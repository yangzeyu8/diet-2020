# %% [markdown]
# # Content-Based Recipe Recommendation

# %% [markdown]
# ## The Recipe Dataset
#
# ### Data Preparation
# Let's load this data into Python. I will load the dataset with Pandas onto Dataframes **ratings**, **users**, and **recipes**.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re
import sys

import seaborn as sns
import wordcloud
from wordcloud import WordCloud, STOPWORDS

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel
import itertools

# %% [markdown]
# Read datasets from CSV files.

# %%
# Reading ratings file
ratings = pd.read_csv('ratings.csv')

# Reading users file
users = pd.read_csv('users.csv')

# Reading recipes file. Then select attributes and generate the dataframe for calculation
recipes = pd.read_csv('allrecipes.csv')
recipes = recipes[['recipe_id', 'recipe_name', 'servings',
                      'group_name', 'calories','protein', 
                      'carbohydrates', 'fat', 'ingredients', 'recipe_source']]

# %% [markdown]
# ## Data Exploration
# ### Ratings
# I want to examine the **rating** further. Let's take a look at its summary statistics and distribution.

# %%
# Get summary statistics of rating
print(ratings['rating'].describe())

# Display distribution of rating
sns.set_style('whitegrid')
sns.set(font_scale=1.5)
# %matplotlib inline
sns.countplot(ratings['rating'])
# Out:
# count    105.000000
# mean       2.704762
# std        1.386222
# min        1.000000
# 25%        2.000000
# 50%        3.000000
# 75%        4.000000
# max        5.000000
# Name: rating, dtype: float64

# %% [markdown]
# ### Genres
# The genres variable will surely be important while building the recommendation engines since it describes the content of the recipe.

# %%
# Make a census of the group_name keywords
group_name_labels = set()
for s in recipes['group_name'].str.split('|').values:
    group_name_labels = group_name_labels.union(set(s))

# Function that counts the number of times each of the group_name keywords appear
def count_word(dataset, ref_col, census):
    keyword_count = dict()
    for s in census: 
        keyword_count[s] = 0
    for census_keywords in dataset[ref_col].str.split('|'):        
        if type(census_keywords) == float and pd.isnull(census_keywords): 
            continue        
        for s in [s for s in census_keywords if s in census]: 
            if pd.notnull(s): 
                keyword_count[s] += 1

    # convert the dictionary in a list to sort the keywords by frequency
    keyword_occurences = []
    for k,v in keyword_count.items():
        keyword_occurences.append([k,v])
    keyword_occurences.sort(key = lambda x:x[1], reverse = True)
    return keyword_occurences, keyword_count

# Calling this function gives access to a list of group_name keywords which are sorted by decreasing frequency
keyword_occurences, dum = count_word(recipes, 'group_name', group_name_labels)
keyword_occurences[:5]

# Define the dictionary used to produce the genre wordcloud
group_names = dict()
trunc_occurences = keyword_occurences[0:18]
for s in trunc_occurences:
    group_names[s[0]] = s[1]

# Create the wordcloud
group_name_wordcloud = WordCloud(width=1000,height=400, background_color='white')
group_name_wordcloud.generate_from_frequencies(group_names)

# Plot the wordcloud
f, ax = plt.subplots(figsize=(16, 8))
plt.imshow(group_name_wordcloud, interpolation="bilinear")
plt.axis('off')
plt.show()

# %% [markdown]
# ### Ingredients
# The ingredients variable will be also important while building the recommendation engines because it significantly affect flavors.

# %%
pattern = re.compile(".+?'(.+?)'")
ingredients = np.zeros(recipes.shape[0])
ingredients = pd.Series(ingredients)
for i in range(recipes.shape[0]):
    temp = pattern.findall(recipes['ingredients'][i])
    temp = '|'.join(temp)
    ingredients[i] = temp
recipes['ingredients'] = ingredients

# %% [markdown]
# ### Dataset
# I merge recipes, ratings, and users to create a dataset.

# %%
# Join all 3 files into one dataframe
dataset = pd.merge(pd.merge(recipes, ratings),users)\

# Display 20 recipes with highest ratings
dataset[['recipe_name','group_name','rating','ingredients']].sort_values('rating', ascending=False).head(10)
# Out:
#                                           recipe_name  \
# 52                  Slow Cooker Chicken and Dumplings
# 85           Slow Cooker Creamy Chicken and Dumplings
# 47                                   Herbed Dumplings
# 48  Mom's Chicken and Dumplings (Slow Cooker Version)
# 59                  Chef John's Chicken and Dumplings
# 68                   Super Easy Chicken and Dumplings
# 78  Mom's Chicken and Dumplings (Slow Cooker Version)
# 79   Better than Cracker Barrel® Chicken 'n Dumplings
# 83                   Super Easy Chicken and Dumplings
# 82                  Slow Cooker Chicken and Dumplings
#
#                                            group_name  rating  \
# 52  Slow Cooker Recipes|Chicken and Dumpling Recip...       5
# 85  Soup, Stew & Chili Recipes|Chicken and Dumplin...       5
# 47  Soup, Stew & Chili Recipes|Chicken and Dumplin...       5
# 48  Soup, Stew & Chili Recipes|Chicken and Dumplin...       5
# 59  Soup, Stew & Chili Recipes|Chicken and Dumplin...       5
# 68  Soup, Stew & Chili Recipes|Chicken and Dumplin...       5
# 78  Soup, Stew & Chili Recipes|Chicken and Dumplin...       5
# 79  Soup, Stew & Chili Recipes|Chicken and Dumplin...       5
# 83  Soup, Stew & Chili Recipes|Chicken and Dumplin...       5
# 82  Slow Cooker Recipes|Chicken and Dumpling Recip...       5
#
#                                           ingredients
# 52  4 skinless, boneless chicken breast halves|2 t...
# 85  4 skinless, boneless chicken breast halves|2 (...
# 47  1\u2009½ cups all-purpose flour|1 teaspoon sal...
# 48  4 (14.5 ounce) cans chicken broth|3 (12.5 fl o...
# 59  1 (3 to 3 1/2 pound) whole chicken|2\u2009½ qu...
# 68  2 (10.5 ounce) cans cream of chicken soup|3 (1...
# 78  4 (14.5 ounce) cans chicken broth|3 (12.5 fl o...
# 79  1 whole chicken|1 pinch salt|water to cover|1 ...
# 83  2 (10.5 ounce) cans cream of chicken soup|3 (1...
# 82  4 skinless, boneless chicken breast halves|2 t...

# %% [markdown]
# ##  Content-Based Recommendation
# The Content-Based Recommender relies on the similarity of the items being recommended. The basic idea is that if you like an item, then you will also like a “similar” item. It generally works well when it's easy to determine the context/properties of each item.
#
# A content based recommender works with data that the user provides, either explicitly recipe ratings for the allrecipes dataset. Based on that data, a user profile is generated, which is then used to make suggestions to the user. As the user provides more inputs or takes actions on the recommendations, the engine becomes more and more accurate.
#
# ### Theory
# The concepts of **Term Frequency (TF)** and **Inverse Document Frequency (IDF)** are used in information retrieval systems and also content based filtering mechanisms (such as a content based recommender). They are used to determine the relative importance of a document / article / news item / movie etc.
#
# TF is simply the frequency of a word in a document. IDF is the inverse of the document frequency among the whole corpus of documents. TF-IDF is used mainly because of two reasons: Suppose we search for “**the results of latest European Socccer games**” on Google. It is certain that “**the**” will occur more frequently than “**soccer games**” but the relative importance of **soccer games** is higher than the search query point of view. In such cases, TF-IDF weighting negates the effect of high frequency words in determining the importance of an item (document).
#
# Below is the equation to calculate the TF-IDF score:
# <img src="images/tfidf.jpg" alt="tfidf" style="zoom:75%;" />
#
# After calculating TF-IDF scores, how do we determine which items are closer to each other, rather closer to the user profile? This is accomplished using the **Vector Space Model** which computes the proximity based on the angle between the vectors. In this model, each item is stored as a vector of its attributes (which are also vectors) in an **n-dimensional space** and the angles between the vectors are calculated to **determine the similarity between the vectors**. Next, the user profile vectors are also created based on his actions on previous attributes of items and the similarity between an item and a user is also determined in a similar way.
#
# <img src="images/vector_space.png" alt="vector-space" style="zoom:67%;" />
#
# Sentence 2 is more likely to be using Term 2 than using Term 1. Vice-versa for Sentence 1. The method of calculating this relative measure is calculated by taking the cosine of the angle between the sentences and the terms. The ultimate reason behind using cosine is that the **value of cosine will increase with decreasing value of the angle** between which signifies more similarity. The vectors are length normalized after which they become vectors of length 1 and then the cosine calculation is simply the sum-product of vectors.
#
# ### Implementation (Most Similar Recipes)
# With all that theory in mind, I am going to build a Content-Based Recommendation Engine that computes similarity between recipes based on recipe genres and ingredients. It will suggest recipes that are most similar to a particular recipe based on its genre. To do so, I will make use of the file **recipes.csv**.

# %%
# Break up the big string into a string array
feature = recipes['group_name'].str.split('|') + recipes['ingredients'].str.split('|')
print(feature)

# Convert to string value
feature = feature.fillna("").astype('str')
# Out:
# 0        [Chicken Thigh Recipes, Soup, Stew & Chili Rec...
# 1        [Soup, Stew & Chili Recipes, Chicken and Dumpl...
# 2        [Soup, Stew & Chili Recipes, Chicken and Dumpl...
# 3        [Soup, Stew & Chili Recipes, Chicken and Dumpl...
# 4        [Soup, Stew & Chili Recipes, Chicken and Dumpl...
# 5        [Soup, Stew & Chili Recipes, Chicken and Dumpl...
# 6        [Low Cholesterol Recipes, Quick Bread Recipes,...
# 7        [Slow Cooker Recipes, Chicken and Dumpling Rec...
# 8        [Soup, Stew & Chili Recipes, Chicken and Dumpl...
# 9        [Soup, Stew & Chili Recipes, Chicken and Dumpl...
# 10       [Soup, Stew & Chili Recipes, Chicken and Dumpl...
# 11       [Soup, Stew & Chili Recipes, Chicken and Dumpl...
# 12       [Chicken Thigh Recipes, Soup, Stew & Chili Rec...
# 13       [Soup, Stew & Chili Recipes, Chicken and Dumpl...
# 14       [Soup, Stew & Chili Recipes, Chicken and Dumpl...
# 15       [Soup, Stew & Chili Recipes, Chicken and Dumpl...
# 16       [Soup, Stew & Chili Recipes, Chicken and Dumpl...
# 17       [Soup, Stew & Chili Recipes, Chicken and Dumpl...
# 18       [Soup, Stew & Chili Recipes, Chicken and Dumpl...
# 19       [Soup, Stew & Chili Recipes, Chicken and Dumpl...
# 20       [Soup, Stew & Chili Recipes, Chicken and Dumpl...
# 21       [Soup, Stew & Chili Recipes, Chicken and Dumpl...
# 22       [Soup, Stew & Chili Recipes, Chicken and Dumpl...
# 23       [Soup, Stew & Chili Recipes, Chicken and Dumpl...
# 24       [Soup, Stew & Chili Recipes, Chicken and Dumpl...
# 25       [Soup, Stew & Chili Recipes, Chicken and Dumpl...
# 26       [Soup, Stew & Chili Recipes, Chicken and Dumpl...
# 27       [Soup, Stew & Chili Recipes, Chicken and Dumpl...
# 28       [Soup, Stew & Chili Recipes, Chicken and Dumpl...
# 29       [Soup, Stew & Chili Recipes, Chicken and Dumpl...
#                                ...
# 26555    [Lunch and Dinner Recipes, 1 pound spaghetti, ...
# 26556    [Lunch and Dinner Recipes, 2 tablespoons sesam...
# 26557    [Lunch and Dinner Recipes, 5 tablespoons olive...
# 26558    [Lunch and Dinner Recipes, ¾ cup water, 6 tabl...
# 26559    [Lunch and Dinner Recipes, 2 cups chopped pist...
# 26560    [Lunch and Dinner Recipes, 6 raw chop with ref...
# 26561    [Lunch and Dinner Recipes, 1 pheasant, cleaned...
# 26562    [Lunch and Dinner Recipes, 4 raw chop with ref...
# 26563    [Lunch and Dinner Recipes, 2 cups crushed pota...
# 26564    [Lunch and Dinner Recipes, 1 pound ground beef...
# 26565    [Lunch and Dinner Recipes, 1 (8 pound) ham, 20...
# 26566    [Lunch and Dinner Recipes, 1 (16 ounce) packag...
# 26567    [Lunch and Dinner Recipes, 2 tablespoons canol...
# 26568    [Lunch and Dinner Recipes, 5 cups farfalle (bo...
# 26569    [Lunch and Dinner Recipes, 1 (5 pound) pork sh...
# 26570    [Lunch and Dinner Recipes, 8 raw chop with ref...
# 26571    [Lunch and Dinner Recipes, 3 cups chicken brot...
# 26572    [Lunch and Dinner Recipes, 2 tablespoons finel...
# 26573    [Lunch and Dinner Recipes, 1\u2009½ pounds gro...
# 26574    [Lunch and Dinner Recipes, 1 CAULIPOWER® Margh...
# 26575    [Lunch and Dinner Recipes, 6 cups water, 2 cup...
# 26576    [Lunch and Dinner Recipes, ¾ cup distilled whi...
# 26577    [Lunch and Dinner Recipes, 1 (4 pound) whole c...
# 26578    [Lunch and Dinner Recipes, 2 tablespoons olive...
# 26579    [Lunch and Dinner Recipes, ½ cup white wine, 3...
# 26580    [Lunch and Dinner Recipes, ¾ cup pine nuts, ½ ...
# 26581    [Lunch and Dinner Recipes, 1\u2009½ pounds por...
# 26582    [Lunch and Dinner Recipes, 1 tablespoon olive ...
# 26583    [Lunch and Dinner Recipes, 2 cups bread crumbs...
# 26584    [Lunch and Dinner Recipes, 1 (12 ounce) packag...
# Length: 26585, dtype: object

# %% [markdown]
# I do not have a quantitative metric to judge our machine's performance so this will have to be done qualitatively. In order to do so, I'll use **TfidfVectorizer** function from **scikit-learn**, which transforms text to feature vectors that can be used as input to estimator.

# %%
tf = TfidfVectorizer(analyzer='word',ngram_range=(1, 2),min_df=0, stop_words='english')
tfidf_matrix = tf.fit_transform(feature)
tfidf_matrix.shape
# Out:
# (26585, 63877)

# %% [markdown]
# I will be using the **[Cosine Similarity](https://masongallo.github.io/machine/learning,/python/2016/07/29/cosine-similarity.html)** to calculate a numeric quantity that denotes the similarity between two recipes. Since we have used the TF-IDF Vectorizer, calculating the Dot Product will directly give us the Cosine Similarity Score. Therefore, we will use sklearn's **linear_kernel** instead of cosine_similarities since it is much faster.

# %%
cosine_sim = linear_kernel(tfidf_matrix, tfidf_matrix)
cosine_sim[:4, :4]
# Out:
# array([[1.        , 0.23318686, 0.29238929, 0.13302168],
#        [0.23318686, 1.        , 0.34745206, 0.17120908],
#        [0.29238929, 0.34745206, 1.        , 0.22899682],
#        [0.13302168, 0.17120908, 0.22899682, 1.        ]])

# %% [markdown]
# I now have a pairwise cosine similarity matrix for all the recipes in the dataset. The next step is to write a function that returns the 20 most similar recipes based on the cosine similarity score.

# %%
# Build a 1-dimensional array with recipe names
recipe_name = recipes['recipe_name']
recipe_source = recipes['recipe_source']
indices = pd.Series(recipes.index, index=recipes['recipe_name'])

# Function that get recipe recommendations based on the cosine similarity score of recipe genres and ingredients
def name_recommendations(name, allergy):
    # The selected recipe
    idx = indices[name]
    sim_scores = list(enumerate(cosine_sim[idx]))
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    sim_scores = sim_scores[1:31]
    recipe_indices = [i[0] for i in sim_scores]
    
    # Remove recieps that the user is allergic to
    user_allergy = allergy.split('|')
    removed_idx = []
    for i in recipe_indices:
        for j in range(len(user_allergy)):
            if user_allergy[j] in recipes['ingredients'][i]:
                print('The user is allergic to this recipe '+ recipe_name.iloc[i])
                removed_idx.append(i)
                break
    for i in range(len(removed_idx)):
        if removed_idx[i] in recipe_indices:
            recipe_indices.remove(removed_idx[i])
    return recipe_indices, pd.concat([recipe_name.iloc[recipe_indices], recipe_source.iloc[recipe_indices]],axis=1)

# %% [markdown]
# Let's try and get the top recommendations for a few recipes and see how good the recommendations are.

# %%
recipe_indices_1, recommendations_1 = name_recommendations('Breakfast Cups', 'peanut|sesame|lobster')

# %%
recommendations_1
# Out:
#                                          recipe_name  \
# 15721                           AB's Breakfast Pizza
# 13357                          Dad's Breakfast Pizza
# 14695                           Paleo Scrambled Eggs
# 14285                             Breakfast Cupcakes
# 12962              Sausage, Egg, and Cheese Scramble
# 13071                       Microwave Scrambled Eggs
# 16297                        Easy Breakfast Cupcakes
# 13167                      Best Scrambled Eggs Ever!
# 13969  Cheesy Sausage and Potato Breakfast Casserole
# 14797            Emma's Humongous Yorkshire Puddings
# 13315                                Breakfast Pizza
# 14179                     Quick Creamed Ham and Eggs
# 15444              Super Easy Breakfast Sausage Loaf
# 16475                     Individual Baked Frittatas
# 13939     Biscuits and Sausage Gravy Breakfast Pizza
# 13681                    Susie's Breakfast Casserole
# 13978                     Grilled Cheese Brunch Bake
# 16433       Sarah's Savoury Bread and Cheese Pudding
# 12897                          Bacon-and-Egg Muffins
# 15334                   Brown Rice Skillet Breakfast
# 12861                              Hash Brown Quiche
# 13540              K-Dub's Sausage and Egg Casserole
# 16137                         Leftover Turkey Quiche
# 12506                              Breakfast Pizza I
# 16135                    Weekend Breakfast Casserole
# 12805                   Biscuits and Gravy Casserole
# 13864                          Unbelievable Popovers
# 13996                             Cold Oven Popovers
# 13610                Ham and Cheese Omelet Casserole
# 15723                               Ham and Egg Cups
#
#                                            recipe_source
# 15721  https://www.allrecipes.com/recipe/260694/abs-b...
# 13357  https://www.allrecipes.com/recipe/218228/dads-...
# 14695  https://www.allrecipes.com/recipe/258969/paleo...
# 14285  https://www.allrecipes.com/recipe/260262/break...
# 12962  https://www.allrecipes.com/recipe/21661/sausag...
# 13071  https://www.allrecipes.com/recipe/272190/micro...
# 16297  https://www.allrecipes.com/recipe/260264/easy-...
# 13167  https://www.allrecipes.com/recipe/74997/best-s...
# 13969  https://www.allrecipes.com/recipe/261267/chees...
# 14797  https://www.allrecipes.com/recipe/258262/emmas...
# 13315  https://www.allrecipes.com/recipe/228222/break...
# 14179  https://www.allrecipes.com/recipe/237315/quick...
# 15444  https://www.allrecipes.com/recipe/219186/super...
# 16475  https://www.allrecipes.com/recipe/275464/indiv...
# 13939  https://www.allrecipes.com/recipe/260678/biscu...
# 13681  https://www.allrecipes.com/recipe/241107/susie...
# 13978  https://www.allrecipes.com/recipe/246484/grill...
# 16433  https://www.allrecipes.com/recipe/23885/sarahs...
# 12897  https://www.allrecipes.com/recipe/236040/bacon...
# 15334  https://www.allrecipes.com/recipe/240887/brown...
# 12861  https://www.allrecipes.com/recipe/43475/hash-b...
# 13540  https://www.allrecipes.com/recipe/220850/k-dub...
# 16137  https://www.allrecipes.com/recipe/268445/lefto...
# 12506  https://www.allrecipes.com/recipe/20697/breakf...
# 16135  https://www.allrecipes.com/recipe/261277/weeke...
# 12805  https://www.allrecipes.com/recipe/245119/biscu...
# 13864  https://www.allrecipes.com/recipe/20178/unbeli...
# 13996  https://www.allrecipes.com/recipe/23006/cold-o...
# 13610  https://www.allrecipes.com/recipe/14749/ham-an...
# 15723  https://www.allrecipes.com/recipe/256961/ham-a...

# %%
recipe_indices_2, recommendations_2 = name_recommendations('Chef John\'s Chinese Scallion Pancakes','peanut|sesame|lobster')
# Out:
# The user is allergic to this recipe Pan-Fried Chinese Pancakes
# The user is allergic to this recipe Cong You Bing (Chinese Scallion Pancakes)
# The user is allergic to this recipe Peanut Butter and Jelly Bread
# The user is allergic to this recipe Asian Ground Beef Noodle Bowls
# The user is allergic to this recipe Perfect Pot Stickers
# The user is allergic to this recipe Lazy Pork Dumplings
# The user is allergic to this recipe Mongolian Beef I
# The user is allergic to this recipe Chinese Sesame Doughnuts

# %%
recommendations_2
# Out:
#                                              recipe_name  \
# 4285                                   Green Onion Cakes
# 4389                         Chinese Hand-Pulled Noodles
# 4963                                        Roomali Roti
# 4475                                 Green Onion Pancake
# 4498               Traditional Chinese Scallion Pancakes
# 15123                                       Berber Bread
# 13789                              Spiced Maple Pancakes
# 11222                              Deep Dish Pizza Dough
# 4813                                Indian Chapati Bread
# 4337                           Chinese Scallion Pancakes
# 21534                     Poor Man's Chicken Fried Steak
# 14023                                 Date and Nut Bread
# 18936  Torta Salgada de Liquidificador (Savory Brazil...
# 11462                                   Romanov Piroshki
# 15261                              Golden Penny Pancakes
# 4938                                  Indian Sweet Bread
# 19644                         Blue Caramelized Stromboli
# 4252                                Chinese Steamed Buns
# 493                                  Jo's Rosemary Bread
# 12472                        Extra-Yummy Fluffy Pancakes
# 18487                              Jean's Zucchini Salad
# 4504                         Chinese Green Onion Pancake
#
#                                            recipe_source
# 4285   https://www.allrecipes.com/recipe/203178/green...
# 4389   https://www.allrecipes.com/recipe/256982/chine...
# 4963   https://www.allrecipes.com/recipe/17288/roomal...
# 4475   https://www.allrecipes.com/recipe/260521/green...
# 4498   https://www.allrecipes.com/recipe/260479/tradi...
# 15123  https://www.allrecipes.com/recipe/91057/berber...
# 13789  https://www.allrecipes.com/recipe/229257/spice...
# 11222  https://www.allrecipes.com/recipe/241635/deep-...
# 4813   https://www.allrecipes.com/recipe/85469/indian...
# 4337   https://www.allrecipes.com/recipe/234472/chine...
# 21534  https://www.allrecipes.com/recipe/218651/poor-...
# 14023  https://www.allrecipes.com/recipe/15366/date-a...
# 18936  https://www.allrecipes.com/recipe/247386/torta...
# 11462  https://www.allrecipes.com/recipe/21591/romano...
# 15261  https://www.allrecipes.com/recipe/21011/golden...
# 4938   https://www.allrecipes.com/recipe/20034/indian...
# 19644  https://www.allrecipes.com/recipe/256947/blue-...
# 4252   https://www.allrecipes.com/recipe/7011/chinese...
# 493    https://www.allrecipes.com/recipe/17256/jos-ro...
# 12472  https://www.allrecipes.com/recipe/216755/extra...
# 18487  https://www.allrecipes.com/recipe/232094/jeans...
# 4504   https://www.allrecipes.com/recipe/260481/chine...

# %% [markdown]
# ### Implementation (Favourite Features)
#
# The user will select their favourite features and the model will return recipes correspoding to those features.

# %%
def feature_recommendations(like, allergy):
    # User's favourite feature
    recipes_length = len(feature)
    user_like_feature = feature
    temps = like.split('|')
    
    for i in range(len(temps)):
        user_like = pd.Series(str(temps[i].split('&&')))
        user_like_feature[recipes_length+i] = user_like[0]
    
    # Convert to string value
    user_like_feature_str = user_like_feature.fillna("").astype('str')
    user_like_tfidf_matrix = tf.fit_transform(user_like_feature_str)
    user_like_cosine_sim = linear_kernel(user_like_tfidf_matrix, user_like_tfidf_matrix)
    
    # The index of user_like vector
    union = []
    for i in range(len(temps)):
        
        idx = len(user_like_feature)-(i+1)
        sim_scores = list(enumerate(user_like_cosine_sim[idx]))
        sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
        sim_scores = sim_scores[1:31]
        recipe_indices = [i[0] for i in sim_scores]
    
        # Remove recieps that the user is allergic to
        user_allergy = allergy.split('|')
        removed_idx = []
        for i in recipe_indices:
            for j in range(len(user_allergy)):
                if user_allergy[j] in recipes['ingredients'][i]:
                    print('The user is allergic to this recipe '+ recipe_name.iloc[i])
                    removed_idx.append(i)
                    break
        for i in range(len(removed_idx)):
            if removed_idx[i] in recipe_indices:
                recipe_indices.remove(removed_idx[i])
        union.append(recipe_indices)
    return union

# %%
user_like = 'ice cream | (salty && Chinese)'
user_allergy = 'peanut|sesame|lobster'
union = feature_recommendations(user_like, user_allergy)
# Out:
# The user is allergic to this recipe Chinese Noodle Pancakes with Asparagus
# The user is allergic to this recipe Hoisin-Glazed Chicken Thighs
# The user is allergic to this recipe Congee
# The user is allergic to this recipe Kung Pao Chicken Stir-Fry
# The user is allergic to this recipe Fiery Pepper Chicken
# The user is allergic to this recipe Chinese Pork Dumplings
# The user is allergic to this recipe Easy Pan-Fried Fish Fillet
# The user is allergic to this recipe Velveting Chicken Breast, Chinese Restaurant-Style
# The user is allergic to this recipe Chinese Five Spice Spare Ribs
# The user is allergic to this recipe Taiwanese Fried Tofu

# %%
union
# Out:
# [[4419,
#   4341,
#   1298,
#   21581,
#   4575,
#   4261,
#   4238,
#   4249,
#   2955,
#   4462,
#   22178,
#   23221,
#   22493,
#   17170,
#   20096,
#   4369,
#   4476,
#   25912,
#   4362,
#   19591],
#  [15938,
#   2807,
#   2781,
#   2791,
#   2797,
#   2776,
#   2783,
#   2793,
#   2784,
#   2792,
#   2799,
#   1841,
#   2773,
#   13367,
#   12993,
#   2795,
#   9813,
#   2794,
#   2803,
#   2786,
#   2787,
#   14426,
#   14923,
#   14925,
#   1818,
#   2796,
#   2805,
#   2790,
#   13614,
#   2775]]

# %% [markdown]
# ### Implementation (User's Profile)
#
# Based on user's previous decisions (e.g. selected recieps, favourite features) and the user's general setting, we can create a user' profile vector to recommend recipes if user do not have any settings at first.

# %% [markdown]
# Basically this part is the combination of most similar recipes and favourite features.
# - Based on user's recent recipe choice:
#     1. Because you chose Beefy Chinese Dumplings: recommmend some similar recipes.
#     2. Because you chose Italian Stuffed Chicken Breast: recommmend some similar recipes.
#     3. Because you chose ...
# - Based on user's favourite features:
#     1. Because you searched Chinese and eggs: recommmend recipes
#     2. Because you searched Italian and cheese: recommend recipes

# %% [markdown]
# ## Combinations
#
# After we get recipes that user likes, we can user linear programming to let the recipes satisfy to user's nutrition goal.

# %%
def nutrition_recommendations(recipe_indices, num_family_member, num_of_recipes, ref_per, lb_per, ub_per):
    X = list(range(0,len(recipe_indices)))
    nutrition = recipes.iloc[recipe_indices][['calories', 'protein', 'carbohydrates', 'fat']].values
    H = recipes.iloc[recipe_indices][['calories', 'protein', 'carbohydrates', 'fat']]
    H_matrix = nutrition.T # Nutrition information matrix of recipes
    
    ref = ref_per*num_family_member
    lb = lb_per*num_family_member
    ub = ub_per*num_family_member
    max_num_recipe = int(min(ub[0]/min(H_matrix[0]), ub[1]/min(H_matrix[1]), ub[2]/min(H_matrix[2]), ub[3]/min(H_matrix[3])))
    print('The maximum number of recipes satisfying the nutrition constraint we can select is: '+str(max_num_recipe))

    if num_of_recipes <= max_num_recipe:
        combinations = list(itertools.combinations(X,num_of_recipes)) # All combinations, no replacement

        X_matrix_combinations = []
        recipe_combination = []
        recipe_cost = []
        for combination in combinations:
            X_matrix = np.zeros([len(recipe_indices_4),1]) # This represents which recipes do we select
            recipe_index = []
            for j in list(combination):
                X_matrix[j] += 1
                recipe_index.append(recipe_indices_4[j])

            b_matrix = np.dot(H_matrix,X_matrix) # User's total nutrition
            if (lb <= b_matrix).all() & (b_matrix <= ub).all():
                cost = sum(abs(b_matrix - ref)/ref) # The discomfort cost of one combination
                X_matrix_combinations.append(X_matrix)
                recipe_combination.append(recipe_index)
                recipe_cost.append(cost)

        recipe_combination_index = []
        sorted_recipe_cost = sorted(recipe_cost)
        # This will give user 5 choices, could be more, they are sorted by the discomfort cost
        for i in range(5):
            recipe_combination_index.append(recipe_cost.index(sorted_recipe_cost[i]))

        results = list(range(5))
        for i in range(5):   
            results[i] = pd.concat([recipe_name.iloc[recipe_combination[recipe_combination_index[i]]], 
                                    recipe_source.iloc[recipe_combination[recipe_combination_index[i]]]],
                                   axis=1)
        return results
    else:
        print('To satisfy your nutrition constraints, please choose no larger than '+str(max_num_recipe)+' recipes.')

# %% [markdown]
# This part is the input from user.

# %%
ref_per = np.zeros([4,1])
ref_per[0] = 700 # prefered value of calories
ref_per[1] = 35 # prefered value of protein
ref_per[2] = 40 # prefered value of carbohydrates
ref_per[3] = 10 # prefered value of fat

lb_per = np.zeros([4,1])
lb_per[0] = 400 # lower boundary of calories
lb_per[1] = 25 # lower boundary of protein
lb_per[2] = 30 # lower boundary of carbohydrates
lb_per[3] = 7 # lower boundary of fat

ub_per = np.zeros([4,1])
ub_per[0] = 1000 # upper boundary of calories
ub_per[1] = 70 # upper boundary of protein
ub_per[2] = 70 # upper boundary of carbohydrates
ub_per[3] = 50 # upper boundary of fat

# %% [markdown]
# Get recommendations.

# %%
# list(set(recipe_indices_3 + recipe_indices_4)) # This is for (Chinese & egg) | (Italian & cheese)
rcmds = nutrition_recommendations(recipe_indices_4,num_family_member=3,num_of_recipes=4,ref_per=ref_per,
                                  lb_per=lb_per,ub_per=ub_per) # Recommend combinations of Italian & cheese

# %% [markdown]
# The following results are the optimal, sub-optimal solutions and so on. In this circumstance, we have 3 family members and 4 recipes (Italian & cheese).

# %%
rcmds[0]

# %%
rcmds[1]

# %%
rcmds[2]
