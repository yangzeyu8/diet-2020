# %% [markdown]
# ## Recipe Scraper for allrecipes.com

# %% [markdown]
# ### Input of the model
# #### 1. homepage
# 	- This is the recipe website.
#     - eg. 'https://www.allrecipes.com/recipes/78/breakfast-and-brunch/'
# #### 2. numofpage
#     - This is the maximum number of pages.
#     - eg. 'https://www.allrecipes.com/recipes/78/breakfast-and-brunch/?page=194'
# #### 3. path
#     - This is the path you want to save recipe data.
#     - eg. ../data/breakfast
# #### 4. group_name
#     - This is the category of scraped recipes. It should be determined by the programmer manually.
#     - eg. breakfast
#
# By changing above 4 input, the recipe data can be scraped and saved.

# %%
from urllib.request import urlopen, urljoin
from urllib import error
from urllib.parse import urlparse

from urllib.robotparser import RobotFileParser

import requests
from bs4 import BeautifulSoup
import re
import os

import pandas as pd
from pandas import DataFrame
import numpy as np
import json
import time

# %%
def geturls(page):
    dietpage = urlopen(recipepage[page])
    dietsoup = BeautifulSoup(dietpage,'html.parser') 
    urls = []
    recipecard = dietsoup.find_all('div', attrs = {'class':'recipe-card recipeCard'})
    for i in range(len(recipecard)):
        recipe = recipecard[i]
        recipelink = recipe.find_all('a', attrs = {'class':'recipeCard__imageLink'})
        for link in recipelink:
            urls.append(link.get('href'))
    return urls

# %%
'''modify'''
homepage = 'https://www.allrecipes.com/recipes/78/breakfast-and-brunch/' # input
numofpage = 194 # input

recipepage = []
recipepage.append(homepage) 

for i in range(1,numofpage): 
    recipepage.append(homepage+'?page='+str(i+1)) 

print(recipepage)
    
urls = []
for i in range(len(recipepage)):
    for m in range(10):
        try:
            add = geturls(i)
            print('get page '+str(i)+' all the recipe urls')
            time.sleep(0.1)
            break
        except Exception as e:
            if m >= 9:
                print(e)
            else:
                time.sleep(0.1)
    urls = urls + add
# Out:
# ['https://www.allrecipes.com/recipes/731/world-cuisine/european/greek/', 'https://www.allrecipes.com/recipes/731/world-cuisine/european/greek/?page=2', 'https://www.allrecipes.com/recipes/731/world-cuisine/european/greek/?page=3', 'https://www.allrecipes.com/recipes/731/world-cuisine/european/greek/?page=4', 'https://www.allrecipes.com/recipes/731/world-cuisine/european/greek/?page=5', 'https://www.allrecipes.com/recipes/731/world-cuisine/european/greek/?page=6', 'https://www.allrecipes.com/recipes/731/world-cuisine/european/greek/?page=7', 'https://www.allrecipes.com/recipes/731/world-cuisine/european/greek/?page=8', 'https://www.allrecipes.com/recipes/731/world-cuisine/european/greek/?page=9', 'https://www.allrecipes.com/recipes/731/world-cuisine/european/greek/?page=10', 'https://www.allrecipes.com/recipes/731/world-cuisine/european/greek/?page=11', 'https://www.allrecipes.com/recipes/731/world-cuisine/european/greek/?page=12', 'https://www.allrecipes.com/recipes/731/world-cuisine/european/greek/?page=13', 'https://www.allrecipes.com/recipes/731/world-cuisine/european/greek/?page=14', 'https://www.allrecipes.com/recipes/731/world-cuisine/european/greek/?page=15', 'https://www.allrecipes.com/recipes/731/world-cuisine/european/greek/?page=16', 'https://www.allrecipes.com/recipes/731/world-cuisine/european/greek/?page=17', 'https://www.allrecipes.com/recipes/731/world-cuisine/european/greek/?page=18', 'https://www.allrecipes.com/recipes/731/world-cuisine/european/greek/?page=19', 'https://www.allrecipes.com/recipes/731/world-cuisine/european/greek/?page=20', 'https://www.allrecipes.com/recipes/731/world-cuisine/european/greek/?page=21']
# get page 0 all the recipe urls
# get page 1 all the recipe urls
# get page 2 all the recipe urls
# get page 3 all the recipe urls
# get page 4 all the recipe urls
# get page 5 all the recipe urls
# get page 6 all the recipe urls
# get page 7 all the recipe urls
# get page 8 all the recipe urls
# get page 9 all the recipe urls
# get page 10 all the recipe urls
# get page 11 all the recipe urls
# get page 12 all the recipe urls
# get page 13 all the recipe urls
# get page 14 all the recipe urls
# get page 15 all the recipe urls
# get page 16 all the recipe urls
# get page 17 all the recipe urls
# get page 18 all the recipe urls
# get page 19 all the recipe urls
# get page 20 all the recipe urls

# %%
class recipeinfo:
    '''Yes'''
    def __init__(self, url):
        for i in range(10):
            try:
                self.recipepage = urlopen(url)
                time.sleep(0.1)
                break            
            except Exception as e:
                if i >= 9:
                    print(e)
                else:
                    time.sleep(0.1)
        self.recipesoup = BeautifulSoup(self.recipepage,'html.parser')
        
    '''Yes'''
    def getname(self):
        self.name = self.recipesoup.find(attrs = {'class':'headline heading-content'})
        try:
            self.name = self.name.string
        except AttributeError:
            self.name = 'unknown'
        self.name = self.name.replace('/',' or ')
        self.name = self.name.replace('"', '')
        return self.name
        
    
    '''Yes'''
    def getsummary(self):
        try:
            self.summary = self.recipesoup.find(attrs = {'class':'recipe-summary margin-8-bottom'})
        except Exception as e:
            print(e)
            self.summary = 'not known'
        try:
            self.paragraph = self.summary.find(attrs = {'class':'margin-0-auto'})
            self.paragraph = self.paragraph.string
        except Exception as e:
            print(e)
            self.paragraph = 'not known'
        return self.paragraph
    
    '''Yes'''
    def getauthor(self):
        self.author = self.recipesoup.find(attrs = {'class':'author-name link'})
        try: 
            self.author = self.author.string
        except AttributeError:
            self.author = 'unknown'
        try:
            self.authorlink = self.author.get('href')
        except AttributeError:
            self.authorlink = 'unknown'
        return self.author
        return self.authorlink
    
    '''Yes'''
    def getrecipeinfo(self):
        try:
            self.recipeinfo = self.recipesoup.find_all(attrs = {'class':'recipe-meta-item-body'})
            self.infolist = []
            for info in self.recipeinfo:
                info = info.string
                info = info.replace('\n','')
                info = re.sub(' +', ' ', info)
                info = info.strip()
                self.infolist.append(info)
            self.infolist[-2] = int(self.infolist[-2])
        except Exception as e:
            print(e)
            self.infolist = [1,'none']
        return self.infolist
    
    '''Yes'''
    def getingredients(self):
        try:
            self.ingredients = self.recipesoup.find_all(attrs = {'class':'ingredients-item-name'})
            self.ingredientslist = []
            for ingredient in self.ingredients:
                self.ingredientslist.append(ingredient.string)

            for i in range(len(self.ingredientslist)):
                self.ingredientslist[i] = self.ingredientslist[i].replace('\n','')
                self.ingredientslist[i] = re.sub(' +', ' ', self.ingredientslist[i])
                self.ingredientslist[i] = self.ingredientslist[i].strip()
        except Exception as e:
            print(e)
            self.ingredientslist = ['not known']
        return self.ingredientslist

    '''Yes'''
    def getdirections(self):
        try:
            self.directions = self.recipesoup.find_all(attrs = {'class':'subcontainer instructions-section-item'})
            self.directionslist = []
            for direction in self.directions:
                direction = direction.find('div')
                direction = direction.find('p')
                direction = direction.string
                self.directionslist.append(direction)
        except Exception as e:
            print(e)
            self.directionslist = ['not known']
        return self.directionslist
    
    '''Yes'''
    def getnutrition(self):
        try:
            self.nutrition = self.recipesoup.find(attrs = {'class':'partial recipe-nutrition-section'})
            self.nutrition = self.nutrition.find(attrs = {'class':'section-body'})
            self.nutrition = self.nutrition.text
            self.nutrition = self.nutrition.replace('Full Nutrition\n','')
            self.nutrition = re.sub(' +', ' ', self.nutrition)
            self.nutrition = self.nutrition.strip()
            self.nutritionlist = self.nutrition.split(';')
        except Exception as e:
            print(e)
            self.nutritionlist = [0,0,0,0,0,0]
        self.nutritionfact = []
        for i in range(len(self.nutritionlist)):
            if i == 0:
                self.nutritionlist[i] = self.nutritionlist[i].replace(' calories','')
                try:
                    self.nutritionlist[i] = float(self.nutritionlist[i])
                except Exception:
                    self.nutritionlist[i] = 0
                self.nutritionfact.append(self.nutritionlist[i])
            if i == 1:
                self.nutritionlist[i] = self.nutritionlist[i].replace(' protein ','')
                self.nutritionlist[i] = self.nutritionlist[i].replace(' DV','')
                temp = self.nutritionlist[i].split('g')
                try:  
                    temp[1] = temp[1].strip()
                    temp[0] = float(temp[0])
                except Exception:
                    temp[0] = 0
                self.nutritionfact.append(temp[0])
            if i == 2:
                self.nutritionlist[i] = self.nutritionlist[i].replace(' carbohydrates ','')
                self.nutritionlist[i] = self.nutritionlist[i].replace(' DV','')
                temp = self.nutritionlist[i].split('g')
                try:  
                    temp[1] = temp[1].strip()
                    temp[0] = float(temp[0])
                except Exception:
                    temp[0] = 0
                self.nutritionfact.append(temp[0])
            if i == 3:
                self.nutritionlist[i] = self.nutritionlist[i].replace(' fat ','')
                self.nutritionlist[i] = self.nutritionlist[i].replace(' DV','')
                temp = self.nutritionlist[i].split('g')
                try:  
                    temp[1] = temp[1].strip()
                    temp[0] = float(temp[0])
                except Exception:
                    temp[0] = 0
                self.nutritionfact.append(temp[0])
            if i == 4:
                self.nutritionlist[i] = self.nutritionlist[i].replace(' cholesterol ','')
                self.nutritionlist[i] = self.nutritionlist[i].replace(' DV','')
                temp = self.nutritionlist[i].split('mg')
                try:  
                    temp[1] = temp[1].strip()
                    temp[0] = float(temp[0])
                except Exception:
                    temp[0] = 0
                self.nutritionfact.append(temp[0])
            if i == 5:
                self.nutritionlist[i] = self.nutritionlist[i].replace(' sodium ','')
                self.nutritionlist[i] = self.nutritionlist[i].replace(' DV','')
                temp = self.nutritionlist[i].split('mg')
                try:  
                    temp[1] = temp[1].strip()
                    temp[0] = float(temp[0])
                except Exception:
                    temp[0] = 0
                self.nutritionfact.append(temp[0])
        return self.nutritionfact

# %%
# Each website is a separate project (folder)
def create_project_dir(directory):
    if not os.path.exists(directory):
        print('Creating directory ' + directory)
        os.makedirs(directory)

# %%
'''modify'''
path = '../data/breakfast' # input
group_name = 'breakfast' # input
create_project_dir(path) # '../data/breakfast'
create_project_dir(path + '/each_'group_name)  # '../data/breakfast/each_breakfast'
output = []
iteration = 0
# Out:
# Creating directory GreekFood
# Creating directory GreekFood/GreekFoodData

# %%
'''modify'''
def recipedata(start,urls,path,group_name):
    '''########################## Make changes ############################'''
    global iteration
    global output
    table = pd.DataFrame(columns = [
                            'model','id','recipe_name','servings','group_name','calories',
                            'protein','carbohydrates','fat','ingredients','recipe_source'
                        ])

    each = pd.DataFrame(columns = [
                            'model','id','recipe_name','servings','group_name','calories',
                            'protein','carbohydrates','fat','ingredients','recipe_source'
                        ])    
    
    for recipeid in range(start,len(urls)):
        iteration = recipeid
        print('Scraping the '+str(recipeid)+'th' + ' recipe')
    
        information = recipeinfo(urls[recipeid])
        information.getname()
        information.getsummary()
        information.getauthor()
        information.getrecipeinfo()
        information.getingredients()
        information.getdirections()
        information.getnutrition()
            
        data = {'model': 'recipes.recipe',
                'id':recipeid+1,
                'recipe_name': information.name,
                'servings': information.infolist[-2],
                'group_name': group_name,
                'calories': information.nutritionfact[0],
                'protein': information.nutritionfact[1],
                'carbohydrates': information.nutritionfact[2],
                'fat': information.nutritionfact[3], 
                'ingredients':information.ingredientslist,
                'recipe_source':urls[recipeid]
               }
        output.append(data)
        print('the len of urls is '+ str(len(urls))+'. the len of output is '+ str(len(output))+'.')
        
        print('Save the accumulated recipes until the '+str(recipeid)+'th' + ' recipe to JSON format')
        with open(path+'/'+group_name+'.json', mode='w', encoding='utf-8') as f: 
            json.dump(output, f)
        
        print('Save the '+str(recipeid)+'th' + ' recipe to CSV format')
        
        each = each.append([{'recipe':'breakfast-' + str(recipeid+1),'model':'recipes.recipe','id':recipeid+1,
                               'recipe_name':information.name,'servings':information.infolist[-2],
                               'group_name':group_name,
                               'calories':information.nutritionfact[0],
                               'protein':information.nutritionfact[1],
                               'carbohydrates':information.nutritionfact[2],
                               'fat':information.nutritionfact[3],
                               'ingredients':information.ingredientslist,
                               'recipe_source':urls[recipeid]}], ignore_index=True)
        
        each.to_csv(path + '/each_'+group_name+'/'+information.name+'.csv')
        each = pd.DataFrame(columns = [
                                'model','id','recipe_name','servings','group_name','calories',
                                'protein','carbohydrates','fat','ingredients','recipe_source'
                            ])
        print('Save the accumulated recipes until the '+str(recipeid)+'th' + ' recipe to CSV format')
        table = table.append([{'recipe':'breakfast-' + str(recipeid+1),'model':'recipes.recipe','id':recipeid+1,
                               'recipe_name':information.name,'servings':information.infolist[-2],
                               'group_name':group_name,
                               'calories':information.nutritionfact[0],
                               'protein':information.nutritionfact[1],
                               'carbohydrates':information.nutritionfact[2],
                               'fat':information.nutritionfact[3],
                               'ingredients':information.ingredientslist,
                               'recipe_source':urls[recipeid]}], ignore_index=True)
        table.to_csv(path+'/'+group_name+'.csv')
        if len(output) >= len(urls):
            break
        
    print('Save all recipes as JSON file')
    with open(path+'/'+group_name+'.json', mode='w', encoding='utf-8') as f:
        json.dump(output, f)
        # 将字典列表存入json文件中

# %%
'''modify'''
while True:
    print('the len of urls is '+ str(len(urls))+'. the len of output is '+ str(len(output))+'.')
    if len(output) >= len(urls):
        break
    try:
        print('The input iteration is '+str(iteration))
        print('The len of urls is '+ str(len(urls)))
        recipedata(iteration,urls,path,group_name)
    except Exception as e:
        print(e)
        print('The current iter is '+str(iteration)+'. Now input to RecipeJson again.')
        urls.pop(iteration)
        print('The problematic elements in urls has been removed. The len of urls is now '+str(len(urls))+'.')

        with open(path+'/'+group_name+'.json', mode='r', encoding='utf-8') as f:
            output = json.load(f)
# Out:
# The input iteration is 0
# The len of urls is 495
# Scraping the 0th recipe
# Save the accumulated recipes until the 0th recipe to JSON format
# Save the 0th recipe to CSV format
# Scraping the 1th recipe
# Save the accumulated recipes until the 1th recipe to JSON format
# Save the 1th recipe to CSV format
# Scraping the 2th recipe
# Save the accumulated recipes until the 2th recipe to JSON format
# Save the 2th recipe to CSV format
# Scraping the 3th recipe
# Save the accumulated recipes until the 3th recipe to JSON format
# Save the 3th recipe to CSV format
# Scraping the 4th recipe
# Save the accumulated recipes until the 4th recipe to JSON format
# Save the 4th recipe to CSV format
# Scraping the 5th recipe
# Save the accumulated recipes until the 5th recipe to JSON format
# Save the 5th recipe to CSV format
# Scraping the 6th recipe
# Save the accumulated recipes until the 6th recipe to JSON format
# Save the 6th recipe to CSV format
# Scraping the 7th recipe
# Save the accumulated recipes until the 7th recipe to JSON format
# Save the 7th recipe to CSV format
# Scraping the 8th recipe
# Save the accumulated recipes until the 8th recipe to JSON format
# Save the 8th recipe to CSV format
# Scraping the 9th recipe
# Save the accumulated recipes until the 9th recipe to JSON format
# Save the 9th recipe to CSV format
# Scraping the 10th recipe
# Save the accumulated recipes until the 10th recipe to JSON format
# Save the 10th recipe to CSV format
# Scraping the 11th recipe
# Save the accumulated recipes until the 11th recipe to JSON format
# Save the 11th recipe to CSV format
# Scraping the 12th recipe
# Save the accumulated recipes until the 12th recipe to JSON format
# Save the 12th recipe to CSV format
# Scraping the 13th recipe
# Save the accumulated recipes until the 13th recipe to JSON format
# Save the 13th recipe to CSV format
# Scraping the 14th recipe
# Save the accumulated recipes until the 14th recipe to JSON format
# Save the 14th recipe to CSV format
# Scraping the 15th recipe
# Save the accumulated recipes until the 15th recipe to JSON format
# Save the 15th recipe to CSV format
# Scraping the 16th recipe
# Save the accumulated recipes until the 16th recipe to JSON format
# Save the 16th recipe to CSV format
# Scraping the 17th recipe
# Save the accumulated recipes until the 17th recipe to JSON format
# Save the 17th recipe to CSV format
# Scraping the 18th recipe
# Save the accumulated recipes until the 18th recipe to JSON format
# Save the 18th recipe to CSV format
# Scraping the 19th recipe
# Save the accumulated recipes until the 19th recipe to JSON format
# Save the 19th recipe to CSV format
# Scraping the 20th recipe
# Save the accumulated recipes until the 20th recipe to JSON format
# Save the 20th recipe to CSV format
# Scraping the 21th recipe
# Save the accumulated recipes until the 21th recipe to JSON format
# Save the 21th recipe to CSV format
# Scraping the 22th recipe
# Save the accumulated recipes until the 22th recipe to JSON format
# Save the 22th recipe to CSV format
# Scraping the 23th recipe
# Save the accumulated recipes until the 23th recipe to JSON format
# Save the 23th recipe to CSV format
# Scraping the 24th recipe
# Save the accumulated recipes until the 24th recipe to JSON format
# Save the 24th recipe to CSV format
# Scraping the 25th recipe
# Save the accumulated recipes until the 25th recipe to JSON format
# Save the 25th recipe to CSV format
# Scraping the 26th recipe
# Save the accumulated recipes until the 26th recipe to JSON format
# Save the 26th recipe to CSV format
# Scraping the 27th recipe
# Save the accumulated recipes until the 27th recipe to JSON format
# Save the 27th recipe to CSV format
# Scraping the 28th recipe
# Save the accumulated recipes until the 28th recipe to JSON format
# Save the 28th recipe to CSV format
# Scraping the 29th recipe
# Save the accumulated recipes until the 29th recipe to JSON format
# Save the 29th recipe to CSV format
# Scraping the 30th recipe
# Save the accumulated recipes until the 30th recipe to JSON format
# Save the 30th recipe to CSV format
# Scraping the 31th recipe
# Save the accumulated recipes until the 31th recipe to JSON format
# Save the 31th recipe to CSV format
# Scraping the 32th recipe
# Save the accumulated recipes until the 32th recipe to JSON format
# Save the 32th recipe to CSV format
# Scraping the 33th recipe
# Save the accumulated recipes until the 33th recipe to JSON format
# Save the 33th recipe to CSV format
# Scraping the 34th recipe
# Save the accumulated recipes until the 34th recipe to JSON format
# Save the 34th recipe to CSV format
# Scraping the 35th recipe
# Save the accumulated recipes until the 35th recipe to JSON format
# Save the 35th recipe to CSV format
# Scraping the 36th recipe
# Save the accumulated recipes until the 36th recipe to JSON format
# Save the 36th recipe to CSV format
# Scraping the 37th recipe
# Save the accumulated recipes until the 37th recipe to JSON format
# Save the 37th recipe to CSV format
# Scraping the 38th recipe
# Save the accumulated recipes until the 38th recipe to JSON format
# Save the 38th recipe to CSV format
# Scraping the 39th recipe
# Save the accumulated recipes until the 39th recipe to JSON format
# Save the 39th recipe to CSV format
# Scraping the 40th recipe
# Save the accumulated recipes until the 40th recipe to JSON format
# Save the 40th recipe to CSV format
# Scraping the 41th recipe
# Save the accumulated recipes until the 41th recipe to JSON format
# Save the 41th recipe to CSV format
# Scraping the 42th recipe
# Save the accumulated recipes until the 42th recipe to JSON format
# Save the 42th recipe to CSV format
# Scraping the 43th recipe
# Save the accumulated recipes until the 43th recipe to JSON format
# Save the 43th recipe to CSV format
# Scraping the 44th recipe
# Save the accumulated recipes until the 44th recipe to JSON format
# Save the 44th recipe to CSV format
# Scraping the 45th recipe
# Save the accumulated recipes until the 45th recipe to JSON format
# Save the 45th recipe to CSV format
# Scraping the 46th recipe
# Save the accumulated recipes until the 46th recipe to JSON format
# Save the 46th recipe to CSV format
# Scraping the 47th recipe
# Save the accumulated recipes until the 47th recipe to JSON format
# Save the 47th recipe to CSV format
# Scraping the 48th recipe
# Save the accumulated recipes until the 48th recipe to JSON format
# Save the 48th recipe to CSV format
# Scraping the 49th recipe
# Save the accumulated recipes until the 49th recipe to JSON format
# Save the 49th recipe to CSV format
# Scraping the 50th recipe
# Save the accumulated recipes until the 50th recipe to JSON format
# Save the 50th recipe to CSV format
# Scraping the 51th recipe
# Save the accumulated recipes until the 51th recipe to JSON format
# Save the 51th recipe to CSV format
# Scraping the 52th recipe
# Save the accumulated recipes until the 52th recipe to JSON format
# Save the 52th recipe to CSV format
# Scraping the 53th recipe
# Save the accumulated recipes until the 53th recipe to JSON format
# Save the 53th recipe to CSV format
# Scraping the 54th recipe
# Save the accumulated recipes until the 54th recipe to JSON format
# Save the 54th recipe to CSV format
# Scraping the 55th recipe
# Save the accumulated recipes until the 55th recipe to JSON format
# Save the 55th recipe to CSV format
# Scraping the 56th recipe
# Save the accumulated recipes until the 56th recipe to JSON format
# Save the 56th recipe to CSV format
# Scraping the 57th recipe
# Save the accumulated recipes until the 57th recipe to JSON format
# Save the 57th recipe to CSV format
# Scraping the 58th recipe
# Save the accumulated recipes until the 58th recipe to JSON format
# Save the 58th recipe to CSV format
# Scraping the 59th recipe
# Save the accumulated recipes until the 59th recipe to JSON format
# Save the 59th recipe to CSV format
# Scraping the 60th recipe
# Save the accumulated recipes until the 60th recipe to JSON format
# Save the 60th recipe to CSV format
# Scraping the 61th recipe
# Save the accumulated recipes until the 61th recipe to JSON format
# Save the 61th recipe to CSV format
# Scraping the 62th recipe
# Save the accumulated recipes until the 62th recipe to JSON format
# Save the 62th recipe to CSV format
# Scraping the 63th recipe
# Save the accumulated recipes until the 63th recipe to JSON format
# Save the 63th recipe to CSV format
# Scraping the 64th recipe
# Save the accumulated recipes until the 64th recipe to JSON format
# Save the 64th recipe to CSV format
# Scraping the 65th recipe
# Save the accumulated recipes until the 65th recipe to JSON format
# Save the 65th recipe to CSV format
# Scraping the 66th recipe
# Save the accumulated recipes until the 66th recipe to JSON format
# Save the 66th recipe to CSV format
# Scraping the 67th recipe
# Save the accumulated recipes until the 67th recipe to JSON format
# Save the 67th recipe to CSV format
# Scraping the 68th recipe
# Save the accumulated recipes until the 68th recipe to JSON format
# Save the 68th recipe to CSV format
# Scraping the 69th recipe
# Save the accumulated recipes until the 69th recipe to JSON format
# Save the 69th recipe to CSV format
# Scraping the 70th recipe
# Save the accumulated recipes until the 70th recipe to JSON format
# Save the 70th recipe to CSV format
# Scraping the 71th recipe
# Save the accumulated recipes until the 71th recipe to JSON format
# Save the 71th recipe to CSV format
# Scraping the 72th recipe
# Save the accumulated recipes until the 72th recipe to JSON format
# Save the 72th recipe to CSV format
# Scraping the 73th recipe
# Save the accumulated recipes until the 73th recipe to JSON format
# Save the 73th recipe to CSV format
# Scraping the 74th recipe
# Save the accumulated recipes until the 74th recipe to JSON format
# Save the 74th recipe to CSV format
# Scraping the 75th recipe
# Save the accumulated recipes until the 75th recipe to JSON format
# Save the 75th recipe to CSV format
# Scraping the 76th recipe
# Save the accumulated recipes until the 76th recipe to JSON format
# Save the 76th recipe to CSV format
# Scraping the 77th recipe
# Save the accumulated recipes until the 77th recipe to JSON format
# Save the 77th recipe to CSV format
# Scraping the 78th recipe
# Save the accumulated recipes until the 78th recipe to JSON format
# Save the 78th recipe to CSV format
# Scraping the 79th recipe
# Save the accumulated recipes until the 79th recipe to JSON format
# Save the 79th recipe to CSV format
# Scraping the 80th recipe
# Save the accumulated recipes until the 80th recipe to JSON format
# Save the 80th recipe to CSV format
# Scraping the 81th recipe
# Save the accumulated recipes until the 81th recipe to JSON format
# Save the 81th recipe to CSV format
# Scraping the 82th recipe
# Save the accumulated recipes until the 82th recipe to JSON format
# Save the 82th recipe to CSV format
# Scraping the 83th recipe
# Save the accumulated recipes until the 83th recipe to JSON format
# Save the 83th recipe to CSV format
# Scraping the 84th recipe
# Save the accumulated recipes until the 84th recipe to JSON format
# Save the 84th recipe to CSV format
# Scraping the 85th recipe
# Save the accumulated recipes until the 85th recipe to JSON format
# Save the 85th recipe to CSV format
# Scraping the 86th recipe
# Save the accumulated recipes until the 86th recipe to JSON format
# Save the 86th recipe to CSV format
# Scraping the 87th recipe
# Save the accumulated recipes until the 87th recipe to JSON format
# Save the 87th recipe to CSV format
# Scraping the 88th recipe
# Save the accumulated recipes until the 88th recipe to JSON format
# Save the 88th recipe to CSV format
# Scraping the 89th recipe
# Save the accumulated recipes until the 89th recipe to JSON format
# Save the 89th recipe to CSV format
# Scraping the 90th recipe
# Save the accumulated recipes until the 90th recipe to JSON format
# Save the 90th recipe to CSV format
# Scraping the 91th recipe
# Save the accumulated recipes until the 91th recipe to JSON format
# Save the 91th recipe to CSV format
# Scraping the 92th recipe
# Save the accumulated recipes until the 92th recipe to JSON format
# Save the 92th recipe to CSV format
# Scraping the 93th recipe
# Save the accumulated recipes until the 93th recipe to JSON format
# Save the 93th recipe to CSV format
# Scraping the 94th recipe
# Save the accumulated recipes until the 94th recipe to JSON format
# Save the 94th recipe to CSV format
# Scraping the 95th recipe
# Save the accumulated recipes until the 95th recipe to JSON format
# Save the 95th recipe to CSV format
# Scraping the 96th recipe
# Save the accumulated recipes until the 96th recipe to JSON format
# Save the 96th recipe to CSV format
# Scraping the 97th recipe
# Save the accumulated recipes until the 97th recipe to JSON format
# Save the 97th recipe to CSV format
# Scraping the 98th recipe
# Save the accumulated recipes until the 98th recipe to JSON format
# Save the 98th recipe to CSV format
# Scraping the 99th recipe
# Save the accumulated recipes until the 99th recipe to JSON format
# Save the 99th recipe to CSV format
# Scraping the 100th recipe
# Save the accumulated recipes until the 100th recipe to JSON format
# Save the 100th recipe to CSV format
# Scraping the 101th recipe
# Save the accumulated recipes until the 101th recipe to JSON format
# Save the 101th recipe to CSV format
# Scraping the 102th recipe
# Save the accumulated recipes until the 102th recipe to JSON format
# Save the 102th recipe to CSV format
# Scraping the 103th recipe
# Save the accumulated recipes until the 103th recipe to JSON format
# Save the 103th recipe to CSV format
# Scraping the 104th recipe
# Save the accumulated recipes until the 104th recipe to JSON format
# Save the 104th recipe to CSV format
# Scraping the 105th recipe
# Save the accumulated recipes until the 105th recipe to JSON format
# Save the 105th recipe to CSV format
# Scraping the 106th recipe
# Save the accumulated recipes until the 106th recipe to JSON format
# Save the 106th recipe to CSV format
# Scraping the 107th recipe
# Save the accumulated recipes until the 107th recipe to JSON format
# Save the 107th recipe to CSV format
# Scraping the 108th recipe
# Save the accumulated recipes until the 108th recipe to JSON format
# Save the 108th recipe to CSV format
# Scraping the 109th recipe
# Save the accumulated recipes until the 109th recipe to JSON format
# Save the 109th recipe to CSV format
# Scraping the 110th recipe
# Save the accumulated recipes until the 110th recipe to JSON format
# Save the 110th recipe to CSV format
# Scraping the 111th recipe
# Save the accumulated recipes until the 111th recipe to JSON format
# Save the 111th recipe to CSV format
# Scraping the 112th recipe
# Save the accumulated recipes until the 112th recipe to JSON format
# Save the 112th recipe to CSV format
# Scraping the 113th recipe
# Save the accumulated recipes until the 113th recipe to JSON format
# Save the 113th recipe to CSV format
# Scraping the 114th recipe
# Save the accumulated recipes until the 114th recipe to JSON format
# Save the 114th recipe to CSV format
# Scraping the 115th recipe
# Save the accumulated recipes until the 115th recipe to JSON format
# Save the 115th recipe to CSV format
# Scraping the 116th recipe
# Save the accumulated recipes until the 116th recipe to JSON format
# Save the 116th recipe to CSV format
# Scraping the 117th recipe
# Save the accumulated recipes until the 117th recipe to JSON format
# Save the 117th recipe to CSV format
# Scraping the 118th recipe
# Save the accumulated recipes until the 118th recipe to JSON format
# Save the 118th recipe to CSV format
# Scraping the 119th recipe
# Save the accumulated recipes until the 119th recipe to JSON format
# Save the 119th recipe to CSV format
# Scraping the 120th recipe
# Save the accumulated recipes until the 120th recipe to JSON format
# Save the 120th recipe to CSV format
# Scraping the 121th recipe
# Save the accumulated recipes until the 121th recipe to JSON format
# Save the 121th recipe to CSV format
# Scraping the 122th recipe
# Save the accumulated recipes until the 122th recipe to JSON format
# Save the 122th recipe to CSV format
# Scraping the 123th recipe
# Save the accumulated recipes until the 123th recipe to JSON format
# Save the 123th recipe to CSV format
# Scraping the 124th recipe
# Save the accumulated recipes until the 124th recipe to JSON format
# Save the 124th recipe to CSV format
# Scraping the 125th recipe
# Save the accumulated recipes until the 125th recipe to JSON format
# Save the 125th recipe to CSV format
# Scraping the 126th recipe
# Save the accumulated recipes until the 126th recipe to JSON format
# Save the 126th recipe to CSV format
# Scraping the 127th recipe
# Save the accumulated recipes until the 127th recipe to JSON format
# Save the 127th recipe to CSV format
# Scraping the 128th recipe
# Save the accumulated recipes until the 128th recipe to JSON format
# Save the 128th recipe to CSV format
# Scraping the 129th recipe
# Save the accumulated recipes until the 129th recipe to JSON format
# Save the 129th recipe to CSV format
# Scraping the 130th recipe
# Save the accumulated recipes until the 130th recipe to JSON format
# Save the 130th recipe to CSV format
# Scraping the 131th recipe
# Save the accumulated recipes until the 131th recipe to JSON format
# Save the 131th recipe to CSV format
# Scraping the 132th recipe
# Save the accumulated recipes until the 132th recipe to JSON format
# Save the 132th recipe to CSV format
# Scraping the 133th recipe
# Save the accumulated recipes until the 133th recipe to JSON format
# Save the 133th recipe to CSV format
# Scraping the 134th recipe
# Save the accumulated recipes until the 134th recipe to JSON format
# Save the 134th recipe to CSV format
# Scraping the 135th recipe
# Save the accumulated recipes until the 135th recipe to JSON format
# Save the 135th recipe to CSV format
# Scraping the 136th recipe
# Save the accumulated recipes until the 136th recipe to JSON format
# Save the 136th recipe to CSV format
# Scraping the 137th recipe
# Save the accumulated recipes until the 137th recipe to JSON format
# Save the 137th recipe to CSV format
# Scraping the 138th recipe
# Save the accumulated recipes until the 138th recipe to JSON format
# Save the 138th recipe to CSV format
# Scraping the 139th recipe
# Save the accumulated recipes until the 139th recipe to JSON format
# Save the 139th recipe to CSV format
# Scraping the 140th recipe
# Save the accumulated recipes until the 140th recipe to JSON format
# Save the 140th recipe to CSV format
# Scraping the 141th recipe
# Save the accumulated recipes until the 141th recipe to JSON format
# Save the 141th recipe to CSV format
# Scraping the 142th recipe
# Save the accumulated recipes until the 142th recipe to JSON format
# Save the 142th recipe to CSV format
# Scraping the 143th recipe
# Save the accumulated recipes until the 143th recipe to JSON format
# Save the 143th recipe to CSV format
# Scraping the 144th recipe
# Save the accumulated recipes until the 144th recipe to JSON format
# Save the 144th recipe to CSV format
# Scraping the 145th recipe
# Save the accumulated recipes until the 145th recipe to JSON format
# Save the 145th recipe to CSV format
# Scraping the 146th recipe
# Save the accumulated recipes until the 146th recipe to JSON format
# Save the 146th recipe to CSV format
# Scraping the 147th recipe
# Save the accumulated recipes until the 147th recipe to JSON format
# Save the 147th recipe to CSV format
# Scraping the 148th recipe
# Save the accumulated recipes until the 148th recipe to JSON format
# Save the 148th recipe to CSV format
# Scraping the 149th recipe
# Save the accumulated recipes until the 149th recipe to JSON format
# Save the 149th recipe to CSV format
# Scraping the 150th recipe
# Save the accumulated recipes until the 150th recipe to JSON format
# Save the 150th recipe to CSV format
# Scraping the 151th recipe
# Save the accumulated recipes until the 151th recipe to JSON format
# Save the 151th recipe to CSV format
# Scraping the 152th recipe
# Save the accumulated recipes until the 152th recipe to JSON format
# Save the 152th recipe to CSV format
# Scraping the 153th recipe
# Save the accumulated recipes until the 153th recipe to JSON format
# Save the 153th recipe to CSV format
# Scraping the 154th recipe
# Save the accumulated recipes until the 154th recipe to JSON format
# Save the 154th recipe to CSV format
# Scraping the 155th recipe
# Save the accumulated recipes until the 155th recipe to JSON format
# Save the 155th recipe to CSV format
# Scraping the 156th recipe
# Save the accumulated recipes until the 156th recipe to JSON format
# Save the 156th recipe to CSV format
# Scraping the 157th recipe
# Save the accumulated recipes until the 157th recipe to JSON format
# Save the 157th recipe to CSV format
# Scraping the 158th recipe
# Save the accumulated recipes until the 158th recipe to JSON format
# Save the 158th recipe to CSV format
# Scraping the 159th recipe
# Save the accumulated recipes until the 159th recipe to JSON format
# Save the 159th recipe to CSV format
# Scraping the 160th recipe
# Save the accumulated recipes until the 160th recipe to JSON format
# Save the 160th recipe to CSV format
# Scraping the 161th recipe
# Save the accumulated recipes until the 161th recipe to JSON format
# Save the 161th recipe to CSV format
# Scraping the 162th recipe
# Save the accumulated recipes until the 162th recipe to JSON format
# Save the 162th recipe to CSV format
# Scraping the 163th recipe
# Save the accumulated recipes until the 163th recipe to JSON format
# Save the 163th recipe to CSV format
# Scraping the 164th recipe
# Save the accumulated recipes until the 164th recipe to JSON format
# Save the 164th recipe to CSV format
# Scraping the 165th recipe
# Save the accumulated recipes until the 165th recipe to JSON format
# Save the 165th recipe to CSV format
# Scraping the 166th recipe
# Save the accumulated recipes until the 166th recipe to JSON format
# Save the 166th recipe to CSV format
# Scraping the 167th recipe
# Save the accumulated recipes until the 167th recipe to JSON format
# Save the 167th recipe to CSV format
# Scraping the 168th recipe
# Save the accumulated recipes until the 168th recipe to JSON format
# Save the 168th recipe to CSV format
# Scraping the 169th recipe
# Save the accumulated recipes until the 169th recipe to JSON format
# Save the 169th recipe to CSV format
# Scraping the 170th recipe
# Save the accumulated recipes until the 170th recipe to JSON format
# Save the 170th recipe to CSV format
# Scraping the 171th recipe
# Save the accumulated recipes until the 171th recipe to JSON format
# Save the 171th recipe to CSV format
# Scraping the 172th recipe
# Save the accumulated recipes until the 172th recipe to JSON format
# Save the 172th recipe to CSV format
# Scraping the 173th recipe
# Save the accumulated recipes until the 173th recipe to JSON format
# Save the 173th recipe to CSV format
# Scraping the 174th recipe
# Save the accumulated recipes until the 174th recipe to JSON format
# Save the 174th recipe to CSV format
# Scraping the 175th recipe
# Save the accumulated recipes until the 175th recipe to JSON format
# Save the 175th recipe to CSV format
# Scraping the 176th recipe
# Save the accumulated recipes until the 176th recipe to JSON format
# Save the 176th recipe to CSV format
# Scraping the 177th recipe
# Save the accumulated recipes until the 177th recipe to JSON format
# Save the 177th recipe to CSV format
# Scraping the 178th recipe
# Save the accumulated recipes until the 178th recipe to JSON format
# Save the 178th recipe to CSV format
# Scraping the 179th recipe
# Save the accumulated recipes until the 179th recipe to JSON format
# Save the 179th recipe to CSV format
# Scraping the 180th recipe
# Save the accumulated recipes until the 180th recipe to JSON format
# Save the 180th recipe to CSV format
# Scraping the 181th recipe
# Save the accumulated recipes until the 181th recipe to JSON format
# Save the 181th recipe to CSV format
# Scraping the 182th recipe
# Save the accumulated recipes until the 182th recipe to JSON format
# Save the 182th recipe to CSV format
# Scraping the 183th recipe
# Save the accumulated recipes until the 183th recipe to JSON format
# Save the 183th recipe to CSV format
# Scraping the 184th recipe
# Save the accumulated recipes until the 184th recipe to JSON format
# Save the 184th recipe to CSV format
# Scraping the 185th recipe
# Save the accumulated recipes until the 185th recipe to JSON format
# Save the 185th recipe to CSV format
# Scraping the 186th recipe
# Save the accumulated recipes until the 186th recipe to JSON format
# Save the 186th recipe to CSV format
# Scraping the 187th recipe
# Save the accumulated recipes until the 187th recipe to JSON format
# Save the 187th recipe to CSV format
# Scraping the 188th recipe
# Save the accumulated recipes until the 188th recipe to JSON format
# Save the 188th recipe to CSV format
# Scraping the 189th recipe
# Save the accumulated recipes until the 189th recipe to JSON format
# Save the 189th recipe to CSV format
# Scraping the 190th recipe
# Save the accumulated recipes until the 190th recipe to JSON format
# Save the 190th recipe to CSV format
# Scraping the 191th recipe
# Save the accumulated recipes until the 191th recipe to JSON format
# Save the 191th recipe to CSV format
# Scraping the 192th recipe
# Save the accumulated recipes until the 192th recipe to JSON format
# Save the 192th recipe to CSV format
# Scraping the 193th recipe
# Save the accumulated recipes until the 193th recipe to JSON format
# Save the 193th recipe to CSV format
# Scraping the 194th recipe
# Save the accumulated recipes until the 194th recipe to JSON format
# Save the 194th recipe to CSV format
# Scraping the 195th recipe
# Save the accumulated recipes until the 195th recipe to JSON format
# Save the 195th recipe to CSV format
# Scraping the 196th recipe
# Save the accumulated recipes until the 196th recipe to JSON format
# Save the 196th recipe to CSV format
# Scraping the 197th recipe
# Save the accumulated recipes until the 197th recipe to JSON format
# Save the 197th recipe to CSV format
# Scraping the 198th recipe
# Save the accumulated recipes until the 198th recipe to JSON format
# Save the 198th recipe to CSV format
# Scraping the 199th recipe
# Save the accumulated recipes until the 199th recipe to JSON format
# Save the 199th recipe to CSV format
# Scraping the 200th recipe
# Save the accumulated recipes until the 200th recipe to JSON format
# Save the 200th recipe to CSV format
# Scraping the 201th recipe
# Save the accumulated recipes until the 201th recipe to JSON format
# Save the 201th recipe to CSV format
# Scraping the 202th recipe
# Save the accumulated recipes until the 202th recipe to JSON format
# Save the 202th recipe to CSV format
# Scraping the 203th recipe
# Save the accumulated recipes until the 203th recipe to JSON format
# Save the 203th recipe to CSV format
# Scraping the 204th recipe
# Save the accumulated recipes until the 204th recipe to JSON format
# Save the 204th recipe to CSV format
# Scraping the 205th recipe
# Save the accumulated recipes until the 205th recipe to JSON format
# Save the 205th recipe to CSV format
# Scraping the 206th recipe
# Save the accumulated recipes until the 206th recipe to JSON format
# Save the 206th recipe to CSV format
# Scraping the 207th recipe
# Save the accumulated recipes until the 207th recipe to JSON format
# Save the 207th recipe to CSV format
# Scraping the 208th recipe
# Save the accumulated recipes until the 208th recipe to JSON format
# Save the 208th recipe to CSV format
# Scraping the 209th recipe
# Save the accumulated recipes until the 209th recipe to JSON format
# Save the 209th recipe to CSV format
# Scraping the 210th recipe
# Save the accumulated recipes until the 210th recipe to JSON format
# Save the 210th recipe to CSV format
# Scraping the 211th recipe
# Save the accumulated recipes until the 211th recipe to JSON format
# Save the 211th recipe to CSV format
# Scraping the 212th recipe
# Save the accumulated recipes until the 212th recipe to JSON format
# Save the 212th recipe to CSV format
# Scraping the 213th recipe
# Save the accumulated recipes until the 213th recipe to JSON format
# Save the 213th recipe to CSV format
# Scraping the 214th recipe
# Save the accumulated recipes until the 214th recipe to JSON format
# Save the 214th recipe to CSV format
# Scraping the 215th recipe
# Save the accumulated recipes until the 215th recipe to JSON format
# Save the 215th recipe to CSV format
# Scraping the 216th recipe
# Save the accumulated recipes until the 216th recipe to JSON format
# Save the 216th recipe to CSV format
# Scraping the 217th recipe
# Save the accumulated recipes until the 217th recipe to JSON format
# Save the 217th recipe to CSV format
# Scraping the 218th recipe
# Save the accumulated recipes until the 218th recipe to JSON format
# Save the 218th recipe to CSV format
# Scraping the 219th recipe
# Save the accumulated recipes until the 219th recipe to JSON format
# Save the 219th recipe to CSV format
# Scraping the 220th recipe
# Save the accumulated recipes until the 220th recipe to JSON format
# Save the 220th recipe to CSV format
# Scraping the 221th recipe
# Save the accumulated recipes until the 221th recipe to JSON format
# Save the 221th recipe to CSV format
# Scraping the 222th recipe
# Save the accumulated recipes until the 222th recipe to JSON format
# Save the 222th recipe to CSV format
# Scraping the 223th recipe
# Save the accumulated recipes until the 223th recipe to JSON format
# Save the 223th recipe to CSV format
# Scraping the 224th recipe
# Save the accumulated recipes until the 224th recipe to JSON format
# Save the 224th recipe to CSV format
# Scraping the 225th recipe
# Save the accumulated recipes until the 225th recipe to JSON format
# Save the 225th recipe to CSV format
# Scraping the 226th recipe
# Save the accumulated recipes until the 226th recipe to JSON format
# Save the 226th recipe to CSV format
# Scraping the 227th recipe
# Save the accumulated recipes until the 227th recipe to JSON format
# Save the 227th recipe to CSV format
# Scraping the 228th recipe
# Save the accumulated recipes until the 228th recipe to JSON format
# Save the 228th recipe to CSV format
# Scraping the 229th recipe
# Save the accumulated recipes until the 229th recipe to JSON format
# Save the 229th recipe to CSV format
# Scraping the 230th recipe
# Save the accumulated recipes until the 230th recipe to JSON format
# Save the 230th recipe to CSV format
# Scraping the 231th recipe
# Save the accumulated recipes until the 231th recipe to JSON format
# Save the 231th recipe to CSV format
# Scraping the 232th recipe
# Save the accumulated recipes until the 232th recipe to JSON format
# Save the 232th recipe to CSV format
# Scraping the 233th recipe
# Save the accumulated recipes until the 233th recipe to JSON format
# Save the 233th recipe to CSV format
# Scraping the 234th recipe
# Save the accumulated recipes until the 234th recipe to JSON format
# Save the 234th recipe to CSV format
# Scraping the 235th recipe
# Save the accumulated recipes until the 235th recipe to JSON format
# Save the 235th recipe to CSV format
# Scraping the 236th recipe
# Save the accumulated recipes until the 236th recipe to JSON format
# Save the 236th recipe to CSV format
# Scraping the 237th recipe
# Save the accumulated recipes until the 237th recipe to JSON format
# Save the 237th recipe to CSV format
# Scraping the 238th recipe
# Save the accumulated recipes until the 238th recipe to JSON format
# Save the 238th recipe to CSV format
# Scraping the 239th recipe
# Save the accumulated recipes until the 239th recipe to JSON format
# Save the 239th recipe to CSV format
# Scraping the 240th recipe
# Save the accumulated recipes until the 240th recipe to JSON format
# Save the 240th recipe to CSV format
# Scraping the 241th recipe
# Save the accumulated recipes until the 241th recipe to JSON format
# Save the 241th recipe to CSV format
# Scraping the 242th recipe
# Save the accumulated recipes until the 242th recipe to JSON format
# Save the 242th recipe to CSV format
# Scraping the 243th recipe
# Save the accumulated recipes until the 243th recipe to JSON format
# Save the 243th recipe to CSV format
# Scraping the 244th recipe
# Save the accumulated recipes until the 244th recipe to JSON format
# Save the 244th recipe to CSV format
# Scraping the 245th recipe
# Save the accumulated recipes until the 245th recipe to JSON format
# Save the 245th recipe to CSV format
# Scraping the 246th recipe
# Save the accumulated recipes until the 246th recipe to JSON format
# Save the 246th recipe to CSV format
# Scraping the 247th recipe
# Save the accumulated recipes until the 247th recipe to JSON format
# Save the 247th recipe to CSV format
# Scraping the 248th recipe
# Save the accumulated recipes until the 248th recipe to JSON format
# Save the 248th recipe to CSV format
# Scraping the 249th recipe
# Save the accumulated recipes until the 249th recipe to JSON format
# Save the 249th recipe to CSV format
# Scraping the 250th recipe
# Save the accumulated recipes until the 250th recipe to JSON format
# Save the 250th recipe to CSV format
# Scraping the 251th recipe
# Save the accumulated recipes until the 251th recipe to JSON format
# Save the 251th recipe to CSV format
# Scraping the 252th recipe
# Save the accumulated recipes until the 252th recipe to JSON format
# Save the 252th recipe to CSV format
# Scraping the 253th recipe
# Save the accumulated recipes until the 253th recipe to JSON format
# Save the 253th recipe to CSV format
# Scraping the 254th recipe
# Save the accumulated recipes until the 254th recipe to JSON format
# Save the 254th recipe to CSV format
# Scraping the 255th recipe
# Save the accumulated recipes until the 255th recipe to JSON format
# Save the 255th recipe to CSV format
# Scraping the 256th recipe
# Save the accumulated recipes until the 256th recipe to JSON format
# Save the 256th recipe to CSV format
# Scraping the 257th recipe
# Save the accumulated recipes until the 257th recipe to JSON format
# Save the 257th recipe to CSV format
# Scraping the 258th recipe
# Save the accumulated recipes until the 258th recipe to JSON format
# Save the 258th recipe to CSV format
# Scraping the 259th recipe
# Save the accumulated recipes until the 259th recipe to JSON format
# Save the 259th recipe to CSV format
# Scraping the 260th recipe
# Save the accumulated recipes until the 260th recipe to JSON format
# Save the 260th recipe to CSV format
# Scraping the 261th recipe
# Save the accumulated recipes until the 261th recipe to JSON format
# Save the 261th recipe to CSV format
# Scraping the 262th recipe
# Save the accumulated recipes until the 262th recipe to JSON format
# Save the 262th recipe to CSV format
# Scraping the 263th recipe
# Save the accumulated recipes until the 263th recipe to JSON format
# Save the 263th recipe to CSV format
# Scraping the 264th recipe
# Save the accumulated recipes until the 264th recipe to JSON format
# Save the 264th recipe to CSV format
# Scraping the 265th recipe
# Save the accumulated recipes until the 265th recipe to JSON format
# Save the 265th recipe to CSV format
# Scraping the 266th recipe
# Save the accumulated recipes until the 266th recipe to JSON format
# Save the 266th recipe to CSV format
# Scraping the 267th recipe
# Save the accumulated recipes until the 267th recipe to JSON format
# Save the 267th recipe to CSV format
# Scraping the 268th recipe
# Save the accumulated recipes until the 268th recipe to JSON format
# Save the 268th recipe to CSV format
# Scraping the 269th recipe
# Save the accumulated recipes until the 269th recipe to JSON format
# Save the 269th recipe to CSV format
# Scraping the 270th recipe
# Save the accumulated recipes until the 270th recipe to JSON format
# Save the 270th recipe to CSV format
# Scraping the 271th recipe
# Save the accumulated recipes until the 271th recipe to JSON format
# Save the 271th recipe to CSV format
# Scraping the 272th recipe
# Save the accumulated recipes until the 272th recipe to JSON format
# Save the 272th recipe to CSV format
# Scraping the 273th recipe
# Save the accumulated recipes until the 273th recipe to JSON format
# Save the 273th recipe to CSV format
# Scraping the 274th recipe
# Save the accumulated recipes until the 274th recipe to JSON format
# Save the 274th recipe to CSV format
# Scraping the 275th recipe
# Save the accumulated recipes until the 275th recipe to JSON format
# Save the 275th recipe to CSV format
# Scraping the 276th recipe
# Save the accumulated recipes until the 276th recipe to JSON format
# Save the 276th recipe to CSV format
# Scraping the 277th recipe
# Save the accumulated recipes until the 277th recipe to JSON format
# Save the 277th recipe to CSV format
# Scraping the 278th recipe
# Save the accumulated recipes until the 278th recipe to JSON format
# Save the 278th recipe to CSV format
# Scraping the 279th recipe
# Save the accumulated recipes until the 279th recipe to JSON format
# Save the 279th recipe to CSV format
# Scraping the 280th recipe
# Save the accumulated recipes until the 280th recipe to JSON format
# Save the 280th recipe to CSV format
# Scraping the 281th recipe
# Save the accumulated recipes until the 281th recipe to JSON format
# Save the 281th recipe to CSV format
# Scraping the 282th recipe
# Save the accumulated recipes until the 282th recipe to JSON format
# Save the 282th recipe to CSV format
# Scraping the 283th recipe
# Save the accumulated recipes until the 283th recipe to JSON format
# Save the 283th recipe to CSV format
# Scraping the 284th recipe
# Save the accumulated recipes until the 284th recipe to JSON format
# Save the 284th recipe to CSV format
# Scraping the 285th recipe
# Save the accumulated recipes until the 285th recipe to JSON format
# Save the 285th recipe to CSV format
# Scraping the 286th recipe
# Save the accumulated recipes until the 286th recipe to JSON format
# Save the 286th recipe to CSV format
# Scraping the 287th recipe
# Save the accumulated recipes until the 287th recipe to JSON format
# Save the 287th recipe to CSV format
# Scraping the 288th recipe
# Save the accumulated recipes until the 288th recipe to JSON format
# Save the 288th recipe to CSV format
# Scraping the 289th recipe
# Save the accumulated recipes until the 289th recipe to JSON format
# Save the 289th recipe to CSV format
# Scraping the 290th recipe
# Save the accumulated recipes until the 290th recipe to JSON format
# Save the 290th recipe to CSV format
# Scraping the 291th recipe
# Save the accumulated recipes until the 291th recipe to JSON format
# Save the 291th recipe to CSV format
# Scraping the 292th recipe
# Save the accumulated recipes until the 292th recipe to JSON format
# Save the 292th recipe to CSV format
# Scraping the 293th recipe
# Save the accumulated recipes until the 293th recipe to JSON format
# Save the 293th recipe to CSV format
# Scraping the 294th recipe
# Save the accumulated recipes until the 294th recipe to JSON format
# Save the 294th recipe to CSV format
# Scraping the 295th recipe
# Save the accumulated recipes until the 295th recipe to JSON format
# Save the 295th recipe to CSV format
# Scraping the 296th recipe
# Save the accumulated recipes until the 296th recipe to JSON format
# Save the 296th recipe to CSV format
# Scraping the 297th recipe
# Save the accumulated recipes until the 297th recipe to JSON format
# Save the 297th recipe to CSV format
# Scraping the 298th recipe
# Save the accumulated recipes until the 298th recipe to JSON format
# Save the 298th recipe to CSV format
# Scraping the 299th recipe
# Save the accumulated recipes until the 299th recipe to JSON format
# Save the 299th recipe to CSV format
# Scraping the 300th recipe
# Save the accumulated recipes until the 300th recipe to JSON format
# Save the 300th recipe to CSV format
# Scraping the 301th recipe
# Save the accumulated recipes until the 301th recipe to JSON format
# Save the 301th recipe to CSV format
# Scraping the 302th recipe
# Save the accumulated recipes until the 302th recipe to JSON format
# Save the 302th recipe to CSV format
# Scraping the 303th recipe
# Save the accumulated recipes until the 303th recipe to JSON format
# Save the 303th recipe to CSV format
# Scraping the 304th recipe
# Save the accumulated recipes until the 304th recipe to JSON format
# Save the 304th recipe to CSV format
# Scraping the 305th recipe
# Save the accumulated recipes until the 305th recipe to JSON format
# Save the 305th recipe to CSV format
# Scraping the 306th recipe
# Save the accumulated recipes until the 306th recipe to JSON format
# Save the 306th recipe to CSV format
# Scraping the 307th recipe
# Save the accumulated recipes until the 307th recipe to JSON format
# Save the 307th recipe to CSV format
# Scraping the 308th recipe
# Save the accumulated recipes until the 308th recipe to JSON format
# Save the 308th recipe to CSV format
# Scraping the 309th recipe
# Save the accumulated recipes until the 309th recipe to JSON format
# Save the 309th recipe to CSV format
# Scraping the 310th recipe
# Save the accumulated recipes until the 310th recipe to JSON format
# Save the 310th recipe to CSV format
# Scraping the 311th recipe
# Save the accumulated recipes until the 311th recipe to JSON format
# Save the 311th recipe to CSV format
# Scraping the 312th recipe
# Save the accumulated recipes until the 312th recipe to JSON format
# Save the 312th recipe to CSV format
# Scraping the 313th recipe
# Save the accumulated recipes until the 313th recipe to JSON format
# Save the 313th recipe to CSV format
# Scraping the 314th recipe
# Save the accumulated recipes until the 314th recipe to JSON format
# Save the 314th recipe to CSV format
# Scraping the 315th recipe
# Save the accumulated recipes until the 315th recipe to JSON format
# Save the 315th recipe to CSV format
# Scraping the 316th recipe
# Save the accumulated recipes until the 316th recipe to JSON format
# Save the 316th recipe to CSV format
# Scraping the 317th recipe
# Save the accumulated recipes until the 317th recipe to JSON format
# Save the 317th recipe to CSV format
# Scraping the 318th recipe
# Save the accumulated recipes until the 318th recipe to JSON format
# Save the 318th recipe to CSV format
# Scraping the 319th recipe
# Save the accumulated recipes until the 319th recipe to JSON format
# Save the 319th recipe to CSV format
# Scraping the 320th recipe
# Save the accumulated recipes until the 320th recipe to JSON format
# Save the 320th recipe to CSV format
# Scraping the 321th recipe
# Save the accumulated recipes until the 321th recipe to JSON format
# Save the 321th recipe to CSV format
# Scraping the 322th recipe
# Save the accumulated recipes until the 322th recipe to JSON format
# Save the 322th recipe to CSV format
# Scraping the 323th recipe
# Save the accumulated recipes until the 323th recipe to JSON format
# Save the 323th recipe to CSV format
# Scraping the 324th recipe
# Save the accumulated recipes until the 324th recipe to JSON format
# Save the 324th recipe to CSV format
# Scraping the 325th recipe
# Save the accumulated recipes until the 325th recipe to JSON format
# Save the 325th recipe to CSV format
# Scraping the 326th recipe
# Save the accumulated recipes until the 326th recipe to JSON format
# Save the 326th recipe to CSV format
# Scraping the 327th recipe
# Save the accumulated recipes until the 327th recipe to JSON format
# Save the 327th recipe to CSV format
# Scraping the 328th recipe
# Save the accumulated recipes until the 328th recipe to JSON format
# Save the 328th recipe to CSV format
# Scraping the 329th recipe
# Save the accumulated recipes until the 329th recipe to JSON format
# Save the 329th recipe to CSV format
# Scraping the 330th recipe
# Save the accumulated recipes until the 330th recipe to JSON format
# Save the 330th recipe to CSV format
# Scraping the 331th recipe
# Save the accumulated recipes until the 331th recipe to JSON format
# Save the 331th recipe to CSV format
# Scraping the 332th recipe
# Save the accumulated recipes until the 332th recipe to JSON format
# Save the 332th recipe to CSV format
# Scraping the 333th recipe
# Save the accumulated recipes until the 333th recipe to JSON format
# Save the 333th recipe to CSV format
# Scraping the 334th recipe
# Save the accumulated recipes until the 334th recipe to JSON format
# Save the 334th recipe to CSV format
# Scraping the 335th recipe
# Save the accumulated recipes until the 335th recipe to JSON format
# Save the 335th recipe to CSV format
# Scraping the 336th recipe
# Save the accumulated recipes until the 336th recipe to JSON format
# Save the 336th recipe to CSV format
# Scraping the 337th recipe
# Save the accumulated recipes until the 337th recipe to JSON format
# Save the 337th recipe to CSV format
# Scraping the 338th recipe
# Save the accumulated recipes until the 338th recipe to JSON format
# Save the 338th recipe to CSV format
# Scraping the 339th recipe
# Save the accumulated recipes until the 339th recipe to JSON format
# Save the 339th recipe to CSV format
# Scraping the 340th recipe
# Save the accumulated recipes until the 340th recipe to JSON format
# Save the 340th recipe to CSV format
# Scraping the 341th recipe
# Save the accumulated recipes until the 341th recipe to JSON format
# Save the 341th recipe to CSV format
# Scraping the 342th recipe
# Save the accumulated recipes until the 342th recipe to JSON format
# Save the 342th recipe to CSV format
# Scraping the 343th recipe
# Save the accumulated recipes until the 343th recipe to JSON format
# Save the 343th recipe to CSV format
# Scraping the 344th recipe
# Save the accumulated recipes until the 344th recipe to JSON format
# Save the 344th recipe to CSV format
# Scraping the 345th recipe
# Save the accumulated recipes until the 345th recipe to JSON format
# Save the 345th recipe to CSV format
# Scraping the 346th recipe
# Save the accumulated recipes until the 346th recipe to JSON format
# Save the 346th recipe to CSV format
# Scraping the 347th recipe
# Save the accumulated recipes until the 347th recipe to JSON format
# Save the 347th recipe to CSV format
# Scraping the 348th recipe
# Save the accumulated recipes until the 348th recipe to JSON format
# Save the 348th recipe to CSV format
# Scraping the 349th recipe
# Save the accumulated recipes until the 349th recipe to JSON format
# Save the 349th recipe to CSV format
# Scraping the 350th recipe
# Save the accumulated recipes until the 350th recipe to JSON format
# Save the 350th recipe to CSV format
# Scraping the 351th recipe
# Save the accumulated recipes until the 351th recipe to JSON format
# Save the 351th recipe to CSV format
# Scraping the 352th recipe
# Save the accumulated recipes until the 352th recipe to JSON format
# Save the 352th recipe to CSV format
# Scraping the 353th recipe
# Save the accumulated recipes until the 353th recipe to JSON format
# Save the 353th recipe to CSV format
# Scraping the 354th recipe
# Save the accumulated recipes until the 354th recipe to JSON format
# Save the 354th recipe to CSV format
# Scraping the 355th recipe
# Save the accumulated recipes until the 355th recipe to JSON format
# Save the 355th recipe to CSV format
# Scraping the 356th recipe
# Save the accumulated recipes until the 356th recipe to JSON format
# Save the 356th recipe to CSV format
# Scraping the 357th recipe
# Save the accumulated recipes until the 357th recipe to JSON format
# Save the 357th recipe to CSV format
# Scraping the 358th recipe
# Save the accumulated recipes until the 358th recipe to JSON format
# Save the 358th recipe to CSV format
# Scraping the 359th recipe
# Save the accumulated recipes until the 359th recipe to JSON format
# Save the 359th recipe to CSV format
# Scraping the 360th recipe
# Save the accumulated recipes until the 360th recipe to JSON format
# Save the 360th recipe to CSV format
# Scraping the 361th recipe
# Save the accumulated recipes until the 361th recipe to JSON format
# Save the 361th recipe to CSV format
# Scraping the 362th recipe
# Save the accumulated recipes until the 362th recipe to JSON format
# Save the 362th recipe to CSV format
# Scraping the 363th recipe
# Save the accumulated recipes until the 363th recipe to JSON format
# Save the 363th recipe to CSV format
# Scraping the 364th recipe
# Save the accumulated recipes until the 364th recipe to JSON format
# Save the 364th recipe to CSV format
# Scraping the 365th recipe
# Save the accumulated recipes until the 365th recipe to JSON format
# Save the 365th recipe to CSV format
# Scraping the 366th recipe
# Save the accumulated recipes until the 366th recipe to JSON format
# Save the 366th recipe to CSV format
# Scraping the 367th recipe
# Save the accumulated recipes until the 367th recipe to JSON format
# Save the 367th recipe to CSV format
# Scraping the 368th recipe
# Save the accumulated recipes until the 368th recipe to JSON format
# Save the 368th recipe to CSV format
# Scraping the 369th recipe
# Save the accumulated recipes until the 369th recipe to JSON format
# Save the 369th recipe to CSV format
# Scraping the 370th recipe
# Save the accumulated recipes until the 370th recipe to JSON format
# Save the 370th recipe to CSV format
# Scraping the 371th recipe
# Save the accumulated recipes until the 371th recipe to JSON format
# Save the 371th recipe to CSV format
# Scraping the 372th recipe
# Save the accumulated recipes until the 372th recipe to JSON format
# Save the 372th recipe to CSV format
# Scraping the 373th recipe
# Save the accumulated recipes until the 373th recipe to JSON format
# Save the 373th recipe to CSV format
# Scraping the 374th recipe
# Save the accumulated recipes until the 374th recipe to JSON format
# Save the 374th recipe to CSV format
# Scraping the 375th recipe
# Save the accumulated recipes until the 375th recipe to JSON format
# Save the 375th recipe to CSV format
# Scraping the 376th recipe
# Save the accumulated recipes until the 376th recipe to JSON format
# Save the 376th recipe to CSV format
# Scraping the 377th recipe
# Save the accumulated recipes until the 377th recipe to JSON format
# Save the 377th recipe to CSV format
# Scraping the 378th recipe
# Save the accumulated recipes until the 378th recipe to JSON format
# Save the 378th recipe to CSV format
# Scraping the 379th recipe
# Save the accumulated recipes until the 379th recipe to JSON format
# Save the 379th recipe to CSV format
# Scraping the 380th recipe
# Save the accumulated recipes until the 380th recipe to JSON format
# Save the 380th recipe to CSV format
# Scraping the 381th recipe
# Save the accumulated recipes until the 381th recipe to JSON format
# Save the 381th recipe to CSV format
# Scraping the 382th recipe
# Save the accumulated recipes until the 382th recipe to JSON format
# Save the 382th recipe to CSV format
# Scraping the 383th recipe
# Save the accumulated recipes until the 383th recipe to JSON format
# Save the 383th recipe to CSV format
# Scraping the 384th recipe
# Save the accumulated recipes until the 384th recipe to JSON format
# Save the 384th recipe to CSV format
# Scraping the 385th recipe
# Save the accumulated recipes until the 385th recipe to JSON format
# Save the 385th recipe to CSV format
# Scraping the 386th recipe
# Save the accumulated recipes until the 386th recipe to JSON format
# Save the 386th recipe to CSV format
# Scraping the 387th recipe
# Save the accumulated recipes until the 387th recipe to JSON format
# Save the 387th recipe to CSV format
# Scraping the 388th recipe
# Save the accumulated recipes until the 388th recipe to JSON format
# Save the 388th recipe to CSV format
# Scraping the 389th recipe
# Save the accumulated recipes until the 389th recipe to JSON format
# Save the 389th recipe to CSV format
# Scraping the 390th recipe
# Save the accumulated recipes until the 390th recipe to JSON format
# Save the 390th recipe to CSV format
# Scraping the 391th recipe
# Save the accumulated recipes until the 391th recipe to JSON format
# Save the 391th recipe to CSV format
# Scraping the 392th recipe
# Save the accumulated recipes until the 392th recipe to JSON format
# Save the 392th recipe to CSV format
# Scraping the 393th recipe
# Save the accumulated recipes until the 393th recipe to JSON format
# Save the 393th recipe to CSV format
# Scraping the 394th recipe
# Save the accumulated recipes until the 394th recipe to JSON format
# Save the 394th recipe to CSV format
# Scraping the 395th recipe
# Save the accumulated recipes until the 395th recipe to JSON format
# Save the 395th recipe to CSV format
# Scraping the 396th recipe
# Save the accumulated recipes until the 396th recipe to JSON format
# Save the 396th recipe to CSV format
# Scraping the 397th recipe
# Save the accumulated recipes until the 397th recipe to JSON format
# Save the 397th recipe to CSV format
# Scraping the 398th recipe
# Save the accumulated recipes until the 398th recipe to JSON format
# Save the 398th recipe to CSV format
# Scraping the 399th recipe
# Save the accumulated recipes until the 399th recipe to JSON format
# Save the 399th recipe to CSV format
# Scraping the 400th recipe
# Save the accumulated recipes until the 400th recipe to JSON format
# Save the 400th recipe to CSV format
# Scraping the 401th recipe
# Save the accumulated recipes until the 401th recipe to JSON format
# Save the 401th recipe to CSV format
# Scraping the 402th recipe
# Save the accumulated recipes until the 402th recipe to JSON format
# Save the 402th recipe to CSV format
# Scraping the 403th recipe
# Save the accumulated recipes until the 403th recipe to JSON format
# Save the 403th recipe to CSV format
# Scraping the 404th recipe
# Save the accumulated recipes until the 404th recipe to JSON format
# Save the 404th recipe to CSV format
# Scraping the 405th recipe
# Save the accumulated recipes until the 405th recipe to JSON format
# Save the 405th recipe to CSV format
# Scraping the 406th recipe
# Save the accumulated recipes until the 406th recipe to JSON format
# Save the 406th recipe to CSV format
# Scraping the 407th recipe
# Save the accumulated recipes until the 407th recipe to JSON format
# Save the 407th recipe to CSV format
# Scraping the 408th recipe
# Save the accumulated recipes until the 408th recipe to JSON format
# Save the 408th recipe to CSV format
# Scraping the 409th recipe
# Save the accumulated recipes until the 409th recipe to JSON format
# Save the 409th recipe to CSV format
# Scraping the 410th recipe
# Save the accumulated recipes until the 410th recipe to JSON format
# Save the 410th recipe to CSV format
# Scraping the 411th recipe
# Save the accumulated recipes until the 411th recipe to JSON format
# Save the 411th recipe to CSV format
# Scraping the 412th recipe
# Save the accumulated recipes until the 412th recipe to JSON format
# Save the 412th recipe to CSV format
# Scraping the 413th recipe
# Save the accumulated recipes until the 413th recipe to JSON format
# Save the 413th recipe to CSV format
# Scraping the 414th recipe
# Save the accumulated recipes until the 414th recipe to JSON format
# Save the 414th recipe to CSV format
# Scraping the 415th recipe
# Save the accumulated recipes until the 415th recipe to JSON format
# Save the 415th recipe to CSV format
# Scraping the 416th recipe
# Save the accumulated recipes until the 416th recipe to JSON format
# Save the 416th recipe to CSV format
# Scraping the 417th recipe
# Save the accumulated recipes until the 417th recipe to JSON format
# Save the 417th recipe to CSV format
# Scraping the 418th recipe
# Save the accumulated recipes until the 418th recipe to JSON format
# Save the 418th recipe to CSV format
# Scraping the 419th recipe
# Save the accumulated recipes until the 419th recipe to JSON format
# Save the 419th recipe to CSV format
# Scraping the 420th recipe
# Save the accumulated recipes until the 420th recipe to JSON format
# Save the 420th recipe to CSV format
# Scraping the 421th recipe
# Save the accumulated recipes until the 421th recipe to JSON format
# Save the 421th recipe to CSV format
# Scraping the 422th recipe
# Save the accumulated recipes until the 422th recipe to JSON format
# Save the 422th recipe to CSV format
# Scraping the 423th recipe
# Save the accumulated recipes until the 423th recipe to JSON format
# Save the 423th recipe to CSV format
# Scraping the 424th recipe
# Save the accumulated recipes until the 424th recipe to JSON format
# Save the 424th recipe to CSV format
# Scraping the 425th recipe
# Save the accumulated recipes until the 425th recipe to JSON format
# Save the 425th recipe to CSV format
# Scraping the 426th recipe
# Save the accumulated recipes until the 426th recipe to JSON format
# Save the 426th recipe to CSV format
# Scraping the 427th recipe
# Save the accumulated recipes until the 427th recipe to JSON format
# Save the 427th recipe to CSV format
# Scraping the 428th recipe
# Save the accumulated recipes until the 428th recipe to JSON format
# Save the 428th recipe to CSV format
# Scraping the 429th recipe
# Save the accumulated recipes until the 429th recipe to JSON format
# Save the 429th recipe to CSV format
# Scraping the 430th recipe
# Save the accumulated recipes until the 430th recipe to JSON format
# Save the 430th recipe to CSV format
# Scraping the 431th recipe
# Save the accumulated recipes until the 431th recipe to JSON format
# Save the 431th recipe to CSV format
# Scraping the 432th recipe
# Save the accumulated recipes until the 432th recipe to JSON format
# Save the 432th recipe to CSV format
# Scraping the 433th recipe
# Save the accumulated recipes until the 433th recipe to JSON format
# Save the 433th recipe to CSV format
# Scraping the 434th recipe
# Save the accumulated recipes until the 434th recipe to JSON format
# Save the 434th recipe to CSV format
# Scraping the 435th recipe
# Save the accumulated recipes until the 435th recipe to JSON format
# Save the 435th recipe to CSV format
# Scraping the 436th recipe
# Save the accumulated recipes until the 436th recipe to JSON format
# Save the 436th recipe to CSV format
# Scraping the 437th recipe
# Save the accumulated recipes until the 437th recipe to JSON format
# Save the 437th recipe to CSV format
# Scraping the 438th recipe
# Save the accumulated recipes until the 438th recipe to JSON format
# Save the 438th recipe to CSV format
# Scraping the 439th recipe
# Save the accumulated recipes until the 439th recipe to JSON format
# Save the 439th recipe to CSV format
# Scraping the 440th recipe
# Save the accumulated recipes until the 440th recipe to JSON format
# Save the 440th recipe to CSV format
# Scraping the 441th recipe
# Save the accumulated recipes until the 441th recipe to JSON format
# Save the 441th recipe to CSV format
# Scraping the 442th recipe
# Save the accumulated recipes until the 442th recipe to JSON format
# Save the 442th recipe to CSV format
# Scraping the 443th recipe
# Save the accumulated recipes until the 443th recipe to JSON format
# Save the 443th recipe to CSV format
# Scraping the 444th recipe
# Save the accumulated recipes until the 444th recipe to JSON format
# Save the 444th recipe to CSV format
# Scraping the 445th recipe
# Save the accumulated recipes until the 445th recipe to JSON format
# Save the 445th recipe to CSV format
# Scraping the 446th recipe
# Save the accumulated recipes until the 446th recipe to JSON format
# Save the 446th recipe to CSV format
# Scraping the 447th recipe
# Save the accumulated recipes until the 447th recipe to JSON format
# Save the 447th recipe to CSV format
# Scraping the 448th recipe
# Save the accumulated recipes until the 448th recipe to JSON format
# Save the 448th recipe to CSV format
# Scraping the 449th recipe
# Save the accumulated recipes until the 449th recipe to JSON format
# Save the 449th recipe to CSV format
# Scraping the 450th recipe
# Save the accumulated recipes until the 450th recipe to JSON format
# Save the 450th recipe to CSV format
# Scraping the 451th recipe
# Save the accumulated recipes until the 451th recipe to JSON format
# Save the 451th recipe to CSV format
# Scraping the 452th recipe
# Save the accumulated recipes until the 452th recipe to JSON format
# Save the 452th recipe to CSV format
# Scraping the 453th recipe
# Save the accumulated recipes until the 453th recipe to JSON format
# Save the 453th recipe to CSV format
# Scraping the 454th recipe
# Save the accumulated recipes until the 454th recipe to JSON format
# Save the 454th recipe to CSV format
# Scraping the 455th recipe
# Save the accumulated recipes until the 455th recipe to JSON format
# Save the 455th recipe to CSV format
# Scraping the 456th recipe
# Save the accumulated recipes until the 456th recipe to JSON format
# Save the 456th recipe to CSV format
# Scraping the 457th recipe
# Save the accumulated recipes until the 457th recipe to JSON format
# Save the 457th recipe to CSV format
# Scraping the 458th recipe
# Save the accumulated recipes until the 458th recipe to JSON format
# Save the 458th recipe to CSV format
# Scraping the 459th recipe
# Save the accumulated recipes until the 459th recipe to JSON format
# Save the 459th recipe to CSV format
# Scraping the 460th recipe
# Save the accumulated recipes until the 460th recipe to JSON format
# Save the 460th recipe to CSV format
# Scraping the 461th recipe
# Save the accumulated recipes until the 461th recipe to JSON format
# Save the 461th recipe to CSV format
# Scraping the 462th recipe
# Save the accumulated recipes until the 462th recipe to JSON format
# Save the 462th recipe to CSV format
# Scraping the 463th recipe
# Save the accumulated recipes until the 463th recipe to JSON format
# Save the 463th recipe to CSV format
# Scraping the 464th recipe
# Save the accumulated recipes until the 464th recipe to JSON format
# Save the 464th recipe to CSV format
# Scraping the 465th recipe
# Save the accumulated recipes until the 465th recipe to JSON format
# Save the 465th recipe to CSV format
# Scraping the 466th recipe
# Save the accumulated recipes until the 466th recipe to JSON format
# Save the 466th recipe to CSV format
# Scraping the 467th recipe
# Save the accumulated recipes until the 467th recipe to JSON format
# Save the 467th recipe to CSV format
# Scraping the 468th recipe
# Save the accumulated recipes until the 468th recipe to JSON format
# Save the 468th recipe to CSV format
# Scraping the 469th recipe
# Save the accumulated recipes until the 469th recipe to JSON format
# Save the 469th recipe to CSV format
# Scraping the 470th recipe
# Save the accumulated recipes until the 470th recipe to JSON format
# Save the 470th recipe to CSV format
# Scraping the 471th recipe
# Save the accumulated recipes until the 471th recipe to JSON format
# Save the 471th recipe to CSV format
# Scraping the 472th recipe
# Save the accumulated recipes until the 472th recipe to JSON format
# Save the 472th recipe to CSV format
# Scraping the 473th recipe
# Save the accumulated recipes until the 473th recipe to JSON format
# Save the 473th recipe to CSV format
# Scraping the 474th recipe
# Save the accumulated recipes until the 474th recipe to JSON format
# Save the 474th recipe to CSV format
# Scraping the 475th recipe
# Save the accumulated recipes until the 475th recipe to JSON format
# Save the 475th recipe to CSV format
# Scraping the 476th recipe
# Save the accumulated recipes until the 476th recipe to JSON format
# Save the 476th recipe to CSV format
# Scraping the 477th recipe
# Save the accumulated recipes until the 477th recipe to JSON format
# Save the 477th recipe to CSV format
# Scraping the 478th recipe
# Save the accumulated recipes until the 478th recipe to JSON format
# Save the 478th recipe to CSV format
# Scraping the 479th recipe
# Save the accumulated recipes until the 479th recipe to JSON format
# Save the 479th recipe to CSV format
# Scraping the 480th recipe
# Save the accumulated recipes until the 480th recipe to JSON format
# Save the 480th recipe to CSV format
# Scraping the 481th recipe
# Save the accumulated recipes until the 481th recipe to JSON format
# Save the 481th recipe to CSV format
# Scraping the 482th recipe
# Save the accumulated recipes until the 482th recipe to JSON format
# Save the 482th recipe to CSV format
# Scraping the 483th recipe
# Save the accumulated recipes until the 483th recipe to JSON format
# Save the 483th recipe to CSV format
# Scraping the 484th recipe
# Save the accumulated recipes until the 484th recipe to JSON format
# Save the 484th recipe to CSV format
# Scraping the 485th recipe
# Save the accumulated recipes until the 485th recipe to JSON format
# Save the 485th recipe to CSV format
# Scraping the 486th recipe
# Save the accumulated recipes until the 486th recipe to JSON format
# Save the 486th recipe to CSV format
# Scraping the 487th recipe
# Save the accumulated recipes until the 487th recipe to JSON format
# Save the 487th recipe to CSV format
# Scraping the 488th recipe
# Save the accumulated recipes until the 488th recipe to JSON format
# Save the 488th recipe to CSV format
# Scraping the 489th recipe
# Save the accumulated recipes until the 489th recipe to JSON format
# Save the 489th recipe to CSV format
# Scraping the 490th recipe
# Save the accumulated recipes until the 490th recipe to JSON format
# Save the 490th recipe to CSV format
# Scraping the 491th recipe
# Save the accumulated recipes until the 491th recipe to JSON format
# Save the 491th recipe to CSV format
# Scraping the 492th recipe
# Save the accumulated recipes until the 492th recipe to JSON format
# Save the 492th recipe to CSV format
# Scraping the 493th recipe
# Save the accumulated recipes until the 493th recipe to JSON format
# Save the 493th recipe to CSV format
# Scraping the 494th recipe
# Save the accumulated recipes until the 494th recipe to JSON format
# Save the 494th recipe to CSV format
# Save all recipes as JSON file

# %%
'''length check'''
with open(path+'/'+group_name+'.json', mode = 'r', encoding = 'utf-8') as f:
    output = json.load(f)
print('now the len of output is '+ str(len(output)))    
recipe_name = []
for i in range(len(output)):
    recipe_name.append(output[i]['recipe_name'])
setrecipe_name = set(recipe_name)
print('the number of non-repeatable recipe name is' + str(len(setrecipe_name)))
if len(setrecipe_name) == len(recipe_name):
    print('no repeatative elements')
else:
    print('repeatation exists')

recipe_name = []
new = []
for i in range(len(output)):
    if output[i]['recipe_name'] in recipe_name:
        pass
    else:
        recipe_name.append(output[i]['recipe_name'])
        new.append(output[i])
for i in range(len(new)):
    new[i]['id'] = i + 1

with open(path+'/'+group_name+'.json', mode='w', encoding='utf-8') as f:
    json.dump(new,f)
        
with open(path+'/'+group_name+'.json', mode = 'r', encoding = 'utf-8') as f: 
    output = json.load(f)
print('the len of new output is '+ str(len(output)))

# %%
output_old = []
allrecipes_list =  [path+'/'+group_name+'.json'] # other json files with same format can be inserted here.
print(allrecipes_list)
for i in range(len(allrecipes_list)):
    with open(allrecipes_list[i], mode = 'r', encoding = 'utf-8') as f:
        output_old.append(json.load(f))

# %%
'''this function is to merge separate json files into one json file and another csv file'''
def csvjson(allrecipes):

    output  = []
    table = pd.DataFrame(index = [
                            'model','id','recipe_name','servings','group_name','calories',
                            'protein','carbohydrates','fat','ingredients','recipe_source'
                        ])
            
    '''for allrecipes.com'''
    for i in range(len(allrecipes)):
        for recipeid in range(len(allrecipes[i])):
            data = {'model': 'recipes.recipe',
                    'id':recipeid+1,
                    'recipe_name': allrecipes[i][recipeid]['recipe_name'],
                    'servings': int(allrecipes[i][recipeid]['servings']),
                    'group_name': allrecipes[i][recipeid]['group_name'],
                    'calories': float(allrecipes[i][recipeid]['calories']),
                    'protein': float(allrecipes[i][recipeid]['protein']),
                    'carbohydrates': float(allrecipes[i][recipeid]['carbohydrates']),
                    'fat': float(allrecipes[i][recipeid]['fat']),
                    'ingredients': allrecipes[i][recipeid]['ingredients'],
                    'recipe_source': allrecipes[i][recipeid]['recipe_source'],
                   }
            output.append(data)     

            table[allrecipes[i][recipeid]['group_name']+'-id'+str(recipeid+1)] = [
                'recipes.recipe',recipeid+1,allrecipes[i][recipeid]['recipe_name'],int(allrecipes[i][recipeid]['servings']),
                allrecipes[i][recipeid]['group_name'],
                float(allrecipes[i][recipeid]['calories']),
                float(allrecipes[i][recipeid]['protein']),
                float(allrecipes[i][recipeid]['carbohydrates']),
                float(allrecipes[i][recipeid]['fat']),allrecipes[i][recipeid]['ingredients'],
                allrecipes[i][recipeid]['recipe_source']         
            ]
    
    table = table.stack()
    table = table.unstack(0)
    table.to_csv(path+'/'+group_name+'.csv')
        
    print('Save as JSON file')
    with open(path+'/'+group_name+'.json', mode='w', encoding='utf-8') as f:
        json.dump(output, f)

# %%
csvjson(output_old) 
with open(path+'/'+group_name+'.json', mode='r', encoding='utf-8') as f:
    output = json.load(f)
print(len(output))
